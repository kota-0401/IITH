# %% [markdown]
# # **Classification**

# %%
# !pip install simpletransformers
# !pip install ipywidgets --upgrade

import multiprocessing
multiprocessing.set_start_method('spawn', force=True)

import pandas as pd
import json
import sklearn
from simpletransformers.classification import ClassificationModel
from glob import glob
from tqdm import tqdm
import os

# Set environment variables
os.environ['OMP_NUM_THREADS'] = '1'
os.environ['XLA_FLAGS'] = '--xla_cpu_multi_thread_eigen=false'

# Define a mapping for the labels to integers
label_mapping = {'phrase': 0, 'passage': 1, 'multi': 2}

def load_dataset(file_name):
    df = []
    with open('/kaggle/input/webis-clickbait-22/' + file_name) as f:
        for i in f:
            i = json.loads(i)
            tweet = i['postText']
            article_title = i['targetTitle']
            article = ' '.join(i['targetParagraphs'])
            label = i['tags']
            
            assert len(tweet) == 1
            tweet = tweet[0]
            
            assert len(label) == 1
            label = label[0]
            
            if label not in ['phrase', 'passage', 'multi']:
                print(label)
                
            assert label in ['phrase', 'passage', 'multi']
            
            # Add entries to the DataFrame with encoded labels
            df.append({
                'text': tweet + ' - ' + article_title + article,
                'labels': label_mapping[label]  # Encode the label as an integer
            })

    return pd.DataFrame(df)

# Load datasets
test_dataset = load_dataset('test.jsonl')
train_dataset = load_dataset('train.jsonl')
validation_dataset = load_dataset('validation.jsonl')


print("Unique labels in training data:", train_dataset['labels'].unique())

# Define the single configuration
config = {
    "overwrite_output_dir": True,
    "num_train_epochs": 6,
    "fp16": False,
    "train_batch_size": 8,
    "gradient_accumulation_steps": 4,
    "evaluate_during_training": True,
    "max_seq_length": 256,
    "learning_rate": 4e-05,
    "early_stopping_consider_epochs": True,
    "early_stopping_delta": 0.01,
    "early_stopping_metric": "acc",
    "early_stopping_metric_minimize": False,
    "early_stopping_patience": 3,
    "output_dir": "outputs/",
    "save_steps": -1,  # Disable intermediate checkpoints
    "save_best_model": True,  # Only save the best model
    "save_optimizer_and_scheduler": False,   # Save only the model weights
    "use_cuda": True,  # Enable CUDA
    "n_gpu": 2  # Use 2 GPUs for training
}

# Train the model
def train_model(config):
    model = ClassificationModel("roberta", "roberta-large", num_labels=len(label_mapping), args=config)
    model.train_model(train_dataset, eval_df=validation_dataset, acc=sklearn.metrics.accuracy_score)

# Run the training
print('Running the specified configuration')
train_model(config)

# Evaluate the model on validation and test sets
df_results = []
directory = "outputs/"

for checkpoint in tqdm(glob(directory + "checkpoint-*")):
    print(checkpoint)
    model = ClassificationModel("roberta", checkpoint, num_labels=len(label_mapping))
    
    valid_acc = model.eval_model(validation_dataset, acc=sklearn.metrics.accuracy_score)[0]['acc']
    test_acc = model.eval_model(test_dataset, acc=sklearn.metrics.accuracy_score)[0]['acc']
    
    df_results.append({"checkpoint": checkpoint, "valid_acc": valid_acc, "test_acc": test_acc, "config": config})

# Save results to a DataFrame
df_results = pd.DataFrame(df_results)

# Display top results based on validation accuracy
print(df_results[df_results['checkpoint'].str.contains('epoch')].sort_values('valid_acc', ascending=False))
# Out:
# Collecting simpletransformers
#   Downloading simpletransformers-0.70.1-py3-none-any.whl.metadata (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from simpletransformers) (1.26.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from simpletransformers) (2.32.3)
# Requirement already satisfied: tqdm>=4.47.0 in /opt/conda/lib/python3.10/site-packages (from simpletransformers) (4.66.4)
# Requirement already satisfied: regex in /opt/conda/lib/python3.10/site-packages (from simpletransformers) (2024.5.15)
# Requirement already satisfied: transformers>=4.31.0 in /opt/conda/lib/python3.10/site-packages (from simpletransformers) (4.45.1)
# Requirement already satisfied: datasets in /opt/conda/lib/python3.10/site-packages (from simpletransformers) (3.0.1)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from simpletransformers) (1.14.1)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from simpletransformers) (1.2.2)
# Collecting seqeval (from simpletransformers)
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.2 MB/s eta 0:00:00
# done
# Requirement already satisfied: tensorboard in /opt/conda/lib/python3.10/site-packages (from simpletransformers) (2.16.2)
# Requirement already satisfied: tensorboardx in /opt/conda/lib/python3.10/site-packages (from simpletransformers) (2.6.2.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from simpletransformers) (2.2.2)
# Requirement already satisfied: tokenizers in /opt/conda/lib/python3.10/site-packages (from simpletransformers) (0.20.0)
# Requirement already satisfied: wandb>=0.10.32 in /opt/conda/lib/python3.10/site-packages (from simpletransformers) (0.18.3)
# Collecting streamlit (from simpletransformers)
#   Downloading streamlit-1.40.1-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.10/site-packages (from simpletransformers) (0.2.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->simpletransformers) (3.15.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->simpletransformers) (0.25.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->simpletransformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->simpletransformers) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->simpletransformers) (0.4.5)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /opt/conda/lib/python3.10/site-packages (from wandb>=0.10.32->simpletransformers) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from wandb>=0.10.32->simpletransformers) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb>=0.10.32->simpletransformers) (3.1.43)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.10/site-packages (from wandb>=0.10.32->simpletransformers) (3.11.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /opt/conda/lib/python3.10/site-packages (from wandb>=0.10.32->simpletransformers) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb>=0.10.32->simpletransformers) (5.9.3)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb>=0.10.32->simpletransformers) (2.15.0)
# Requirement already satisfied: setproctitle in /opt/conda/lib/python3.10/site-packages (from wandb>=0.10.32->simpletransformers) (1.3.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from wandb>=0.10.32->simpletransformers) (70.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->simpletransformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->simpletransformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->simpletransformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->simpletransformers) (2024.8.30)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets->simpletransformers) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets->simpletransformers) (0.3.8)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets->simpletransformers) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets->simpletransformers) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets->simpletransformers) (2024.6.1)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets->simpletransformers) (3.9.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->simpletransformers) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->simpletransformers) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->simpletransformers) (2024.1)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->simpletransformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->simpletransformers) (3.5.0)
# Requirement already satisfied: altair<6,>=4.0 in /opt/conda/lib/python3.10/site-packages (from streamlit->simpletransformers) (5.4.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from streamlit->simpletransformers) (1.8.2)
# Requirement already satisfied: cachetools<6,>=4.0 in /opt/conda/lib/python3.10/site-packages (from streamlit->simpletransformers) (4.2.4)
# Requirement already satisfied: pillow<12,>=7.1.0 in /opt/conda/lib/python3.10/site-packages (from streamlit->simpletransformers) (10.3.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /opt/conda/lib/python3.10/site-packages (from streamlit->simpletransformers) (13.7.1)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /opt/conda/lib/python3.10/site-packages (from streamlit->simpletransformers) (8.3.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /opt/conda/lib/python3.10/site-packages (from streamlit->simpletransformers) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /opt/conda/lib/python3.10/site-packages (from streamlit->simpletransformers) (4.12.2)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit->simpletransformers)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /opt/conda/lib/python3.10/site-packages (from streamlit->simpletransformers) (6.4.1)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /opt/conda/lib/python3.10/site-packages (from streamlit->simpletransformers) (5.0.3)
# Requirement already satisfied: absl-py>=0.4 in /opt/conda/lib/python3.10/site-packages (from tensorboard->simpletransformers) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/conda/lib/python3.10/site-packages (from tensorboard->simpletransformers) (1.62.2)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard->simpletransformers) (3.6)
# Requirement already satisfied: six>1.9 in /opt/conda/lib/python3.10/site-packages (from tensorboard->simpletransformers) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard->simpletransformers) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard->simpletransformers) (3.0.4)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit->simpletransformers) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /opt/conda/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit->simpletransformers) (4.22.0)
# Requirement already satisfied: narwhals>=1.5.2 in /opt/conda/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit->simpletransformers) (1.9.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->simpletransformers) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->simpletransformers) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->simpletransformers) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->simpletransformers) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->simpletransformers) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->simpletransformers) (4.0.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.10.32->simpletransformers) (4.0.11)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers>=4.31.0->simpletransformers) (3.1.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich<14,>=10.14.0->streamlit->simpletransformers) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich<14,>=10.14.0->streamlit->simpletransformers) (2.18.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard->simpletransformers) (2.1.5)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.10.32->simpletransformers) (5.0.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->simpletransformers) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->simpletransformers) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->simpletransformers) (0.18.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit->simpletransformers) (0.1.2)
# Downloading simpletransformers-0.70.1-py3-none-any.whl (316 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.3/316.3 kB 8.1 MB/s eta 0:00:00
# Downloading streamlit-1.40.1-py2.py3-none-any.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 80.5 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 93.5 MB/s eta 0:00:00
# Building wheels for collected packages: seqeval
# done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16161 sha256=fcdb5c4e12b233bb2e2f81b29b6b55320e0e0494ab60d303e073f36b24bb3224
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
# Successfully built seqeval
# Installing collected packages: pydeck, seqeval, streamlit, simpletransformers
# Successfully installed pydeck-0.9.1 seqeval-1.2.2 simpletransformers-0.70.1 streamlit-1.40.1
# Requirement already satisfied: ipywidgets in /opt/conda/lib/python3.10/site-packages (7.7.1)
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: comm>=0.1.3 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (8.21.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (5.14.3)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets)
#   Downloading widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.12 (from ipywidgets)
#   Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Downloading ipywidgets-8.1.5-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 2.5 MB/s eta 0:00:00
# Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.4/214.4 kB 5.6 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 32.6 MB/s eta 0:00:00
# Installing collected packages: widgetsnbextension, jupyterlab-widgets, ipywidgets
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.9
#     Uninstalling widgetsnbextension-3.6.9:
#       Successfully uninstalled widgetsnbextension-3.6.9
#   Attempting uninstall: jupyterlab-widgets
#     Found existing installation: jupyterlab_widgets 3.0.11
#     Uninstalling jupyterlab_widgets-3.0.11:
#       Successfully uninstalled jupyterlab_widgets-3.0.11
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 0.22.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.10.0, but you have google-cloud-bigquery 2.34.4 which is incompatible.
# bigframes 0.22.0 requires google-cloud-storage>=2.0.0, but you have google-cloud-storage 1.44.0 which is incompatible.
# bigframes 0.22.0 requires pandas<2.1.4,>=1.5.0, but you have pandas 2.2.2 which is incompatible.
# dataproc-jupyter-plugin 0.1.79 requires pydantic~=1.10.0, but you have pydantic 2.9.2 which is incompatible.
# Successfully installed ipywidgets-8.1.5 jupyterlab-widgets-3.0.13 widgetsnbextension-4.0.13
# Unique labels in training data: [1 0 2]
# Running the specified configuration
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-large and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
#   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch:   0%|          | 0/6 [00:00<?, ?it/s]
# Running Epoch 1 of 6:   0%|          | 0/400 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#   0%|          | 0/1 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# Running Epoch 2 of 6:   0%|          | 0/400 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#   0%|          | 0/1 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# Running Epoch 3 of 6:   0%|          | 0/400 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#   0%|          | 0/1 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# Running Epoch 4 of 6:   0%|          | 0/400 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#   0%|          | 0/1 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# Running Epoch 5 of 6:   0%|          | 0/400 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#   0%|          | 0/1 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# Running Epoch 6 of 6:   0%|          | 0/400 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#   0%|          | 0/1 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#   0%|          | 0/6 [00:00<?, ?it/s]
# outputs/checkpoint-200-epoch-2
#   0%|          | 0/1 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/8 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#   0%|          | 0/2 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/10 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#  17%|█▋        | 1/6 [01:03<05:19, 64.00s/it]
# outputs/checkpoint-400-epoch-4
#   0%|          | 0/1 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/8 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#   0%|          | 0/2 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/10 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#  33%|███▎      | 2/6 [02:06<04:13, 63.36s/it]
# outputs/checkpoint-300-epoch-3
#   0%|          | 0/1 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/8 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#   0%|          | 0/2 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/10 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#  50%|█████     | 3/6 [03:09<03:08, 62.98s/it]
# outputs/checkpoint-100-epoch-1
#   0%|          | 0/1 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/8 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#   0%|          | 0/2 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/10 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#  67%|██████▋   | 4/6 [04:19<02:11, 65.82s/it]
# outputs/checkpoint-500-epoch-5
#   0%|          | 0/1 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/8 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#   0%|          | 0/2 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/10 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#  83%|████████▎ | 5/6 [05:21<01:04, 64.55s/it]
# outputs/checkpoint-600-epoch-6
#   0%|          | 0/1 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/8 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#   0%|          | 0/2 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/10 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# 100%|██████████| 6/6 [06:24<00:00, 64.13s/it]
#                        checkpoint  valid_acc  test_acc  \
# 5  outputs/checkpoint-600-epoch-6    0.75250     0.746
# 0  outputs/checkpoint-200-epoch-2    0.74875     0.736
# 1  outputs/checkpoint-400-epoch-4    0.74750     0.741
# 4  outputs/checkpoint-500-epoch-5    0.74750     0.735
# 2  outputs/checkpoint-300-epoch-3    0.71000     0.736
# 3  outputs/checkpoint-100-epoch-1    0.70375     0.706
#
#                                               config
# 5  {'overwrite_output_dir': True, 'num_train_epoc...
# 0  {'overwrite_output_dir': True, 'num_train_epoc...
# 1  {'overwrite_output_dir': True, 'num_train_epoc...
# 4  {'overwrite_output_dir': True, 'num_train_epoc...
# 2  {'overwrite_output_dir': True, 'num_train_epoc...
# 3  {'overwrite_output_dir': True, 'num_train_epoc...

# %%
# Find the checkpoint with the highest test accuracy
checkpoint = df_results.loc[df_results['test_acc'].idxmax(), 'checkpoint']
print(f"Best checkpoint based on test accuracy: {checkpoint}")

print("Evaluating checkpoint:", checkpoint)
model = ClassificationModel("roberta", checkpoint, num_labels=len(label_mapping))

# Validation and test accuracy
valid_acc = model.eval_model(validation_dataset, acc=sklearn.metrics.accuracy_score)[0]['acc']
test_acc = model.eval_model(test_dataset, acc=sklearn.metrics.accuracy_score)[0]['acc']

# Function to collect predictions
def collect_predictions(model, dataset, label_mapping):
    # Reverse the label_mapping to decode predictions
    reverse_label_mapping = {v: k for k, v in label_mapping.items()}

    # Perform predictions
    predictions, _ = model.predict(dataset['text'].tolist())

    # Map numerical predictions back to label names
    predicted_labels = [reverse_label_mapping[pred] for pred in predictions]
    original_labels = [reverse_label_mapping[label] for label in dataset['labels']]

    return predicted_labels, original_labels

# Collect predictions for the test set
predicted_labels, original_labels = collect_predictions(model, test_dataset, label_mapping)

# Print predicted and original labels
print("Predicted and Original Labels:")
for pred, orig in zip(predicted_labels, original_labels):
    print(f"Predicted: {pred}, Original: {orig}")

# Save results to a DataFrame if needed
df_predictions = pd.DataFrame({
    "Original Label": original_labels,
    "Predicted Label": predicted_labels
})

df_predictions.to_csv("outputs/checkpoint_predictions.csv", index=False)

# Output validation and test accuracy
print(f"Validation Accuracy: {valid_acc}")
print(f"Test Accuracy: {test_acc}")
# Out:
# Best checkpoint based on test accuracy: outputs/checkpoint-600-epoch-6
# Evaluating checkpoint: outputs/checkpoint-600-epoch-6
#   0%|          | 0/1 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/8 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#   0%|          | 0/2 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/10 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# Predicted and Original Labels:
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: phrase
# Predicted: passage, Original: passage
# Predicted: multi, Original: multi
# Predicted: passage, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: phrase
# Predicted: multi, Original: passage
# Predicted: phrase, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: phrase
# Predicted: passage, Original: multi
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: multi, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: multi, Original: multi
# Predicted: multi, Original: multi
# Predicted: passage, Original: multi
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: passage
# Predicted: passage, Original: phrase
# Predicted: passage, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: passage
# Predicted: passage, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: phrase, Original: multi
# Predicted: passage, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: phrase
# Predicted: phrase, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: multi, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: multi
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: passage
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: phrase, Original: multi
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: phrase
# Predicted: multi, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: multi, Original: multi
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: multi
# Predicted: passage, Original: passage
# Predicted: phrase, Original: passage
# Predicted: passage, Original: phrase
# Predicted: multi, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: phrase
# Predicted: multi, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: passage
# Predicted: multi, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: multi, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: multi, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: multi, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: multi, Original: phrase
# Predicted: passage, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: multi, Original: passage
# Predicted: multi, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: passage
# Predicted: multi, Original: multi
# Predicted: phrase, Original: multi
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: passage
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: phrase
# Predicted: passage, Original: multi
# Predicted: passage, Original: phrase
# Predicted: multi, Original: multi
# Predicted: multi, Original: multi
# Predicted: phrase, Original: multi
# Predicted: passage, Original: phrase
# Predicted: multi, Original: multi
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: passage
# Predicted: passage, Original: multi
# Predicted: passage, Original: passage
# Predicted: phrase, Original: multi
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: phrase
# Predicted: multi, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: multi
# Predicted: passage, Original: passage
# Predicted: multi, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: multi, Original: passage
# Predicted: phrase, Original: passage
# Predicted: passage, Original: phrase
# Predicted: passage, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: multi
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: passage, Original: multi
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: passage
# Predicted: passage, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: phrase
# Predicted: multi, Original: multi
# Predicted: phrase, Original: multi
# Predicted: phrase, Original: multi
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: passage
# Predicted: multi, Original: multi
# Predicted: multi, Original: phrase
# Predicted: phrase, Original: passage
# Predicted: passage, Original: passage
# Predicted: multi, Original: multi
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: multi
# Predicted: passage, Original: passage
# Predicted: multi, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: multi
# Predicted: passage, Original: passage
# Predicted: multi, Original: multi
# Predicted: multi, Original: multi
# Predicted: passage, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: passage, Original: phrase
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: phrase
# Predicted: phrase, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: phrase
# Predicted: multi, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: phrase, Original: passage
# Predicted: passage, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: multi, Original: multi
# Predicted: passage, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: passage
# Predicted: passage, Original: passage
# Predicted: multi, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: phrase
# Predicted: phrase, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: phrase
# Predicted: multi, Original: multi
# Predicted: phrase, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: passage
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: passage
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: multi, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: multi, Original: multi
# Predicted: multi, Original: passage
# Predicted: passage, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: phrase
# Predicted: multi, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: multi, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: multi, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: multi, Original: multi
# Predicted: phrase, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: multi
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: multi
# Predicted: phrase, Original: passage
# Predicted: passage, Original: multi
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: passage, Original: phrase
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: multi, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: phrase
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: multi, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: passage, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: multi
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: multi, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: multi
# Predicted: passage, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: multi, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: multi
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: phrase
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: multi, Original: phrase
# Predicted: phrase, Original: passage
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: multi
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: multi
# Predicted: passage, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: passage, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: multi
# Predicted: multi, Original: multi
# Predicted: passage, Original: phrase
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: passage
# Predicted: passage, Original: multi
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: phrase
# Predicted: multi, Original: multi
# Predicted: multi, Original: multi
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: multi, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: multi
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: multi, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: multi
# Predicted: passage, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: multi
# Predicted: passage, Original: multi
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: multi
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: multi
# Predicted: multi, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: phrase
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: multi, Original: multi
# Predicted: phrase, Original: passage
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: multi
# Predicted: passage, Original: passage
# Predicted: multi, Original: multi
# Predicted: multi, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: phrase
# Predicted: passage, Original: passage
# Predicted: multi, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: multi, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: multi, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: multi, Original: multi
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: multi, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: passage
# Predicted: multi, Original: multi
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: multi
# Predicted: passage, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: multi, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: phrase
# Predicted: phrase, Original: multi
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: phrase, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: multi, Original: multi
# Predicted: multi, Original: passage
# Predicted: passage, Original: passage
# Predicted: passage, Original: multi
# Predicted: passage, Original: multi
# Predicted: multi, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: phrase
# Predicted: phrase, Original: multi
# Predicted: multi, Original: passage
# Predicted: passage, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: passage, Original: passage
# Predicted: multi, Original: multi
# Predicted: passage, Original: passage
# Predicted: passage, Original: passage
# Predicted: phrase, Original: passage
# Predicted: phrase, Original: multi
# Predicted: passage, Original: multi
# Predicted: phrase, Original: phrase
# Predicted: phrase, Original: phrase
# Validation Accuracy: 0.7525
# Test Accuracy: 0.746

# %% [markdown]
# # **T5-Base**

# %%
# !pip install evaluate
# !pip install simpletransformers
# !pip install ipywidgets --upgrade

import multiprocessing
multiprocessing.set_start_method('spawn', force=True)

from tqdm.auto import tqdm
import evaluate
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, Seq2SeqTrainingArguments, Seq2SeqTrainer
import torch
import numpy as np
from torch.utils.data import Dataset, DataLoader

import os
os.environ["WANDB_MODE"] = "disabled"
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# Collecting evaluate
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: datasets>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from evaluate) (3.0.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from evaluate) (1.26.4)
# Requirement already satisfied: dill in /opt/conda/lib/python3.10/site-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.10/site-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /opt/conda/lib/python3.10/site-packages (from evaluate) (4.66.4)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from evaluate) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.6.1)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from evaluate) (0.25.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from evaluate) (21.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate) (3.15.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate) (16.1.0)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate) (3.9.5)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.7.0->evaluate) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->evaluate) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->evaluate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->evaluate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->evaluate) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->evaluate) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.3
# Requirement already satisfied: simpletransformers in /opt/conda/lib/python3.10/site-packages (0.70.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from simpletransformers) (1.26.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from simpletransformers) (2.32.3)
# Requirement already satisfied: tqdm>=4.47.0 in /opt/conda/lib/python3.10/site-packages (from simpletransformers) (4.66.4)
# Requirement already satisfied: regex in /opt/conda/lib/python3.10/site-packages (from simpletransformers) (2024.5.15)
# Requirement already satisfied: transformers>=4.31.0 in /opt/conda/lib/python3.10/site-packages (from simpletransformers) (4.45.1)
# Requirement already satisfied: datasets in /opt/conda/lib/python3.10/site-packages (from simpletransformers) (3.0.1)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from simpletransformers) (1.14.1)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from simpletransformers) (1.2.2)
# Requirement already satisfied: seqeval in /opt/conda/lib/python3.10/site-packages (from simpletransformers) (1.2.2)
# Requirement already satisfied: tensorboard in /opt/conda/lib/python3.10/site-packages (from simpletransformers) (2.16.2)
# Requirement already satisfied: tensorboardx in /opt/conda/lib/python3.10/site-packages (from simpletransformers) (2.6.2.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from simpletransformers) (2.2.2)
# Requirement already satisfied: tokenizers in /opt/conda/lib/python3.10/site-packages (from simpletransformers) (0.20.0)
# Requirement already satisfied: wandb>=0.10.32 in /opt/conda/lib/python3.10/site-packages (from simpletransformers) (0.18.3)
# Requirement already satisfied: streamlit in /opt/conda/lib/python3.10/site-packages (from simpletransformers) (1.40.1)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.10/site-packages (from simpletransformers) (0.2.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->simpletransformers) (3.15.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->simpletransformers) (0.25.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->simpletransformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->simpletransformers) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->simpletransformers) (0.4.5)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /opt/conda/lib/python3.10/site-packages (from wandb>=0.10.32->simpletransformers) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from wandb>=0.10.32->simpletransformers) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb>=0.10.32->simpletransformers) (3.1.43)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.10/site-packages (from wandb>=0.10.32->simpletransformers) (3.11.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /opt/conda/lib/python3.10/site-packages (from wandb>=0.10.32->simpletransformers) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb>=0.10.32->simpletransformers) (5.9.3)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb>=0.10.32->simpletransformers) (2.15.0)
# Requirement already satisfied: setproctitle in /opt/conda/lib/python3.10/site-packages (from wandb>=0.10.32->simpletransformers) (1.3.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from wandb>=0.10.32->simpletransformers) (70.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->simpletransformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->simpletransformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->simpletransformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->simpletransformers) (2024.8.30)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets->simpletransformers) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets->simpletransformers) (0.3.8)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets->simpletransformers) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets->simpletransformers) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets->simpletransformers) (2024.6.1)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets->simpletransformers) (3.9.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->simpletransformers) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->simpletransformers) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->simpletransformers) (2024.1)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->simpletransformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->simpletransformers) (3.5.0)
# Requirement already satisfied: altair<6,>=4.0 in /opt/conda/lib/python3.10/site-packages (from streamlit->simpletransformers) (5.4.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from streamlit->simpletransformers) (1.8.2)
# Requirement already satisfied: cachetools<6,>=4.0 in /opt/conda/lib/python3.10/site-packages (from streamlit->simpletransformers) (4.2.4)
# Requirement already satisfied: pillow<12,>=7.1.0 in /opt/conda/lib/python3.10/site-packages (from streamlit->simpletransformers) (10.3.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /opt/conda/lib/python3.10/site-packages (from streamlit->simpletransformers) (13.7.1)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /opt/conda/lib/python3.10/site-packages (from streamlit->simpletransformers) (8.3.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /opt/conda/lib/python3.10/site-packages (from streamlit->simpletransformers) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /opt/conda/lib/python3.10/site-packages (from streamlit->simpletransformers) (4.12.2)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /opt/conda/lib/python3.10/site-packages (from streamlit->simpletransformers) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /opt/conda/lib/python3.10/site-packages (from streamlit->simpletransformers) (6.4.1)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /opt/conda/lib/python3.10/site-packages (from streamlit->simpletransformers) (5.0.3)
# Requirement already satisfied: absl-py>=0.4 in /opt/conda/lib/python3.10/site-packages (from tensorboard->simpletransformers) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/conda/lib/python3.10/site-packages (from tensorboard->simpletransformers) (1.62.2)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard->simpletransformers) (3.6)
# Requirement already satisfied: six>1.9 in /opt/conda/lib/python3.10/site-packages (from tensorboard->simpletransformers) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard->simpletransformers) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard->simpletransformers) (3.0.4)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit->simpletransformers) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /opt/conda/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit->simpletransformers) (4.22.0)
# Requirement already satisfied: narwhals>=1.5.2 in /opt/conda/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit->simpletransformers) (1.9.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->simpletransformers) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->simpletransformers) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->simpletransformers) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->simpletransformers) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->simpletransformers) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->simpletransformers) (4.0.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.10.32->simpletransformers) (4.0.11)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers>=4.31.0->simpletransformers) (3.1.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich<14,>=10.14.0->streamlit->simpletransformers) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich<14,>=10.14.0->streamlit->simpletransformers) (2.18.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard->simpletransformers) (2.1.5)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.10.32->simpletransformers) (5.0.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->simpletransformers) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->simpletransformers) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->simpletransformers) (0.18.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit->simpletransformers) (0.1.2)
# Requirement already satisfied: ipywidgets in /opt/conda/lib/python3.10/site-packages (8.1.5)
# Requirement already satisfied: comm>=0.1.3 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (8.21.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)

# %%
# Load datasets from specified paths
dataset = load_dataset(
    'json', 
    data_files={
        'train': '/kaggle/input/webis-clickbait-22/train.jsonl',
        'validation': '/kaggle/input/webis-clickbait-22/validation.jsonl',
        'test': '/kaggle/input/webis-clickbait-22/test.jsonl'
    }
)

train_dataset = dataset['train']
val_dataset = dataset['validation']
test_dataset = dataset['test']
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %%
from simpletransformers.classification import ClassificationModel
import pandas as pd
import torch

import pandas as pd

# # Path to the predictions CSV file
# predictions_file = '/kaggle/input/predictions/checkpoint-3_predictions.csv'

# # Read predictions from the CSV file
# predictions_df = pd.read_csv(predictions_file)

# # Convert the predictions to the correct JSON format
# predictions = predictions_df["Predicted Label"].tolist()

# Update the dataset using map()
test_dataset = test_dataset.map(
    lambda example, idx: {"tags": predicted_labels[idx]},
    with_indices=True
)

print("Updated tags format:")
print(test_dataset[:1])
# Out:
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Updated tags format:
# {'uuid': ['2f3e30d7-972c-4812-b727-6b582de52137'], 'postId': ['420585068076101633'], 'postText': [['This simple household item saves lives']], 'postPlatform': ['Twitter'], 'targetParagraphs': [["Erin Zaikis often used to think about how she could help change the world, but it wasn't until she got very sick with dengue fever that she decided to take action.", "In high school, Zaikis' mother was diagnosed with breast cancer, and the teen slipped into depression -- trapped in what she described as a cycle of feeling sorry for herself. In college, she took a course in global poverty, which helped put her own struggles in perspective. And at 19, the Boston native traveled to Mumbai, where she spent a summer living in an orphanage that housed around 100 girls, some of whom had been left in trash cans or abandoned in train stations.", '"I\'m from a middle-, upper-class town and had never been exposed to extreme poverty, or starvation, or issues like child trafficking," Zaikis said. "It was life-changing."', "After graduating, Zaikis, now 24, traveled to Thailand, where she worked with organizations that fight child trafficking. She visited schools to assess children's risk of being trafficked and to match them with local vocational programs.", "During one such visit, she watched as middle school-age children entered and left a bathroom without washing their hands. With the help of a translator, she asked the children if they had soap, and was startled to learn they didn't know what soap was. The closest shop that sold it was a several-hour walk away. Zaikis made the trek and bought roughly 150 bars of pink and blue soap, which cost her $30 U.S.", '"Cigarettes were much more expensive, but cigarettes were bought by almost everyone in the community," Zaikis said. "I really think the problem did not lie in the cost of soap, but rather the education. No one has spent the time to take these children aside and teach them how to wash their hands."', 'Zaikis knew her soap purchase was a temporary fix, and made plans to spend the summer partnering with schools and local organizations on hygiene projects. But within days, she collapsed and was rushed to the hospital with dengue hemorrhagic fever -- an often deadly infection spread by mosquitos. Her parents took her back to Boston, where she was treated at Massachusetts General Hospital.', '"It was a really horrible couple of months," Zaikis said. "But I think I really needed that because I realized, one, life is short. And two, I could have died of dengue fever if I had stayed in this rural area. ... I felt incredibly fortunate to have survived, and realized I really wanted to dedicate my life to helping other people."', 'Once Zaikis recovered, she took a computer coding class and began searching for soap recipes. "The first soap burnt all my bowls and dishes," she laughed. "I set off the fire alarm. I cut my hand five times." She slowly perfected the process as well as the ingredients, testing her concoctions on herself, then finally on friends and family.', 'Roughly one month ago, Zaikis launched the website for Sundara, where she sells three handmade soaps, each inspired by a different country, and each shaped like a flower.', 'The Thailand soap is scented with lemongrass and pomelo, and a dollar from the sale of each soap supports the Hug Project\'s mission of funding medical professionals who schedule health visits with "street boys" and children at risk of being trafficked, as well as providing them with hygiene kits. Proceeds from the lavender and shea butter soap go to Ghana, where the Unlock Foundation is funding the construction of a sink and well in one school and supplying soap to the area, while proceeds from the chai tea soap go toward Gabriel Project Mumbai, which trains women in the community to lead hygiene workshops in schools located in local slums.', 'The goal, Zaikis said, is to help educate children about hygiene, and to give them the tools to protect themselves -- an uph ...

# %%
model_checkpoint = "t5-base"
model = AutoModelForSeq2SeqLM.from_pretrained(model_checkpoint).to('cuda' if torch.cuda.is_available() else 'cpu')
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)
# Out:
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
def tokenize_function(examples):
    # Create input text by formatting each example
    inputs = [
        f"question: {pt} spoiler type: {tag} context: {tt} - {tp}"
        for tag, pt, tt, tp in zip(examples['tags'], examples['postText'], examples['targetTitle'], examples['targetParagraphs'])
    ]

    # Ensure 'spoiler' is a string; handle multi-part spoilers by joining if they are lists
    labels = [
        spoiler if isinstance(spoiler, str) else " ".join(spoiler)
        for spoiler in examples['spoiler']
    ]

    # Tokenize inputs and labels with consistent padding and truncation
    model_inputs = tokenizer(inputs, max_length=512, truncation=True, padding="max_length")
    label_encodings = tokenizer(labels, max_length=128, truncation=True, padding="max_length")

    # Add labels to model inputs
    model_inputs["labels"] = label_encodings["input_ids"]

    return model_inputs

# Tokenize datasets
train_dataset = train_dataset.map(tokenize_function, batched=True)
val_dataset = val_dataset.map(tokenize_function, batched=True)
test_dataset = test_dataset.map(tokenize_function, batched=True)

# Remove unnecessary columns and set format for PyTorch
train_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])
val_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])
test_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])
# Out:
# Map:   0%|          | 0/3200 [00:00<?, ? examples/s]
# Map:   0%|          | 0/800 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]

# %%
batch_size = 8
model_name = model_checkpoint.split("/")[-1]
args = Seq2SeqTrainingArguments(
    f"{model_name}-finedtuned-qa", 
    evaluation_strategy = "epoch", 
    learning_rate = 2e-3, 
    per_device_train_batch_size = batch_size, 
    per_device_eval_batch_size = batch_size, 
    weight_decay = 0.01, 
    save_strategy="no", 
    num_train_epochs = 3, 
    predict_with_generate = True, 
    push_to_hub = False
)

data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/training_args.py:1545: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
trainer = Seq2SeqTrainer(
    model, 
    args, 
    train_dataset = train_dataset, 
    eval_dataset = val_dataset, 
    data_collator = data_collator, 
    tokenizer = tokenizer, 
)

trainer.train()
# Out:
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# /opt/conda/lib/python3.10/site-packages/transformers/data/data_collator.py:656: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /usr/local/src/pytorch/torch/csrc/utils/tensor_new.cpp:278.)
#   batch["labels"] = torch.tensor(batch["labels"], dtype=torch.int64)
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='600' max='600' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [600/600 17:19, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.233888</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.223551</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.226900</td>
#       <td>0.241845</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=600, training_loss=0.20461056709289552, metrics={'train_runtime': 1041.4006, 'train_samples_per_second': 9.218, 'train_steps_per_second': 0.576, 'total_flos': 5845995749376000.0, 'train_loss': 0.20461056709289552, 'epoch': 3.0})

# %%
from torch.utils.data import DataLoader
from tqdm.auto import tqdm
import torch
import json

# Function for generating predictions and calculating test loss
def test_model(model, dataloader):
    model.eval()
    predictions, references = [], []
    total_loss = 0
    progress_bar = tqdm(dataloader, desc="Generating Predictions and Calculating Test Loss", leave=False)
    with torch.no_grad():
        for batch in progress_bar:
            # Move batch to GPU if available
            inputs = {key: value.to('cuda' if torch.cuda.is_available() else 'cpu') for key, value in batch.items()}
            
            # Calculate outputs and loss
            outputs = model(**inputs)
            loss = outputs.loss
            total_loss += loss.item()
            
            # Generate predictions
            output_sequences = model.generate(input_ids=inputs['input_ids'], attention_mask=inputs['attention_mask'])
            preds = tokenizer.batch_decode(output_sequences, skip_special_tokens=True)
            refs = tokenizer.batch_decode(inputs['labels'], skip_special_tokens=True)
            
            # Store predictions and references
            predictions.extend(preds)
            references.extend(refs)
    
    # Calculate average test loss
    avg_test_loss = total_loss / len(dataloader)
    print(f"Test Loss: {avg_test_loss}")
    return predictions, references, avg_test_loss

# Prepare the test dataloader
test_loader = DataLoader(test_dataset, batch_size=8)

# Generate predictions and references on the test set, and calculate test loss
predictions, references, test_loss = test_model(model, test_loader)

for i in range(len(predictions)):
    print(f"Prediction: {predictions[i]}")
    print(f"Reference: {references[i]}")
    print() 

output_data = {
    "predictions": predictions,
    "references": references
}
with open('/kaggle/working/predictions_references.json', 'w') as f:
    json.dump(output_data, f)
print("Saved predictions, references to /kaggle/working/predictions_references.json")
# Out:
# Generating Predictions and Calculating Test Loss:   0%|          | 0/125 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/transformers/generation/utils.py:1220: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Test Loss: 0.20288528645038606
# Prediction: pink and blue soap
# Reference: soap
#
# Prediction: Gwyneth Paltrow
# Reference: Gwyneth Paltrow
#
# Prediction: they're actually just filming a video for her next album
# Reference: filming the next Nicholas Sparks film
#
# Prediction: JaVale McGee
# Reference: JaVale McGee in Compton
#
# Prediction: Cora
# Reference: Alex Owens-Sarno
#
# Prediction: long after it ends, our first love maintains some power over us. A haunting,
# Reference: Your first experience of something is going to be well remembered, more than later experiences
#
# Prediction: SHOCKIN...
# Reference: Studies have found that where we perceive bacteria thriving in bathrooms can be completely backwards, and what we use to keep us clean could actually be spreading the problem around!
#
# Prediction: chickenwaffles madechicken
# Reference: chickenwaffles
#
# Prediction: "I think the truth will prevail, whatever the process may be, however painful it may be
# Reference: Speaking towards the end of the Tata Chemicals shareholders' meeting that had been called to remove his once close friend Nusli Wadia from the board, Tata said, "These days are very lonely because the newspapers are full of attacks, most of them unsubstantiated but nevertheless very painful."
#
# Prediction: "The Jungle Book" "The Invitation" "The Jungle Book" "Pe
# Reference: "The Jungle Book" "The Invitation" "13th" "Norman Lear: Just Another Version of You" "White Girl"
#
# Prediction: The iPhone's got a crazy-long battery life. And on the most important computer
# Reference: crazy-long battery life
#
# Prediction: The body – which totally isn’t a TV set – was surrounded
# Reference: it’s just a set for TV show
#
# Prediction: Chicago
# Reference: Chicago
#
# Prediction: low thermal conductivity of the burning wood-turned-to-coal, an insul
# Reference: snap a selfie
#
# Prediction: Little Green Cars
# Reference: iTunes Festival Performance
#
# Prediction: "To do it, we have to build a future that is inclusive — not di
# Reference: "To do it, we have to build a future that is inclusive — not divisive — a future which has not only higher incomes but more upward mobility and less inequality, and one which recognizes our diversity because its the only way to honor our common humanity,"
#
# Prediction: No, really. The XFL was never really taken seriously.
# Reference: If you wanted to play, all you had to do was fill out a questionnaire. They loved promoting violence. Three-point conversions were a thing. They practically invented fake news. The P.C. Police weren’t too happy with the Memphis Maniax’s name or logo.
#
# Prediction: Finding Nemo‘s Dory has some marine biologists pretty worried
# Reference: If Finding Dory leads to the same demand for blue tang fish that Finding Nemo did for clown fish, there could be some problems.
#
# Prediction: positive for methamphetamine
# Reference: A woman from California almost lost her newborn baby after testing positive for methamphetamine. The problem? She never used the drug.
#
# Prediction: Chris Duhon
# Reference: Chris Duhon
#
# Prediction: tumor in her left ovary
# Reference: tumor in her left ovary
#
# Prediction: 11,000-foot ridable train track
# Reference: an 11,000-foot ridable train track
#
# Prediction: Charlotte Ronson's New York Home Pops With Bright Colors
# Reference: New York Home Pops With Bright Colors
#
# Prediction: Hispanic
# Reference: Catholic
#
# Prediction: Austin
# Reference: Austin, Texas
#
# Prediction: daughter is a lesbian
# Reference: daughter is a lesbian
#
# Prediction: he was invited to a ceremony at the Quaid-e-Azam University (
# Reference: Move on some 37 years later and Prime Minister Nawaz Sharif on Monday surprised many by approving a plan to rename that same department of the QAU as the Dr Abdus Salam Centre for Physics
#
# Prediction: "You see a gate of expertise for level 999. Only the worthy may pass."
# Reference: In the online MMO Tibia, there's a door with a simple message: "You see a gate of expertise for level 999. Only the worthy may pass." This week, a player named Kharsek passed through that door. It took him nine years to build up enough experience to hit level 999. But once he passed through the door, Kharsek disappeared, and took the secrets with him.
#
# Prediction: Farting can be Toxic
# Reference: It would take a large room of people strapped to space toilets, piped into your victim's breathing mask, or into a gas chamber.
#
# Prediction: breaking his left leg with everyone watching
# Reference: dropped him
#
# Prediction: 3.5mm to Lightning adapter
# Reference: much higher-quality sound draw power from a connected iPhone, iPad or iPod touch through the Lightning port
#
# Prediction: Hillary Clinton’s Nomination Is A Victory For The Smart Girls
# Reference: Hillary Clinton’s Nomination Is A Victory For The Smart Girls Why Am I So Fat? On Making Black Lives Matter Marcia Clark Is Redeemed To The First Lady, With Love
#
# Prediction: He could maybe recover the drone footage he shot on it
# Reference: had to poop it into a pasta strainer and then plug it in to a computer to see if the client’s footage was intact
#
# Prediction: "We Are Men"
# Reference: "We Are Men"
#
# Prediction: ‘Pharaoh’s Serpent’
# Reference: This experiment is called ‘Pharaoh’s Serpent’, for obvious reasons. It looks more like a giant tentacle monster than a simple chemical reaction
#
# Prediction: He was meant to be her happy ever after – a fairytale ending for the prolific
# Reference: A lot of middle-aged women find themselves incredibly lonely and this emotional vulnerability can cause them to make bad choices
#
# Prediction: Microsoft just made the announcement on its German blog (which has since been taken down), warning Windows
# Reference: Microsoft may be over-exaggerating Windows 7’s problems after all, because it uses the same blog post to push Windows 7 users towards Windows 10
#
# Prediction: I would say, 'Yes, you don't have to finish the pitch. I
# Reference: would hate to be clued in on all the spoilers, ruining the show for him as a fan
#
# Prediction: Kevin Love
# Reference: Kevin Love
#
# Prediction: 290 million
# Reference: between 10 and 25 million
#
# Prediction: Rep. Peter King (R-N.Y.) on Sunday slammed
# Reference: Rep. Peter King (R-N.Y.)
#
# Prediction: 1. Tallulah Bankhead 2. Anne Lister 3. Gladys Bentley 4. Hannah S
# Reference: 1. Tallulah Bankhead 2. Anne Lister 3. Gladys Bentley 4. Hannah Snell 5. Marion Barbara "Joe" Carstairs
#
# Prediction: David Schwimmer
# Reference: David Schwimmer
#
# Prediction: The photo appears to show three humps moving out of the cool waters of the Scottish lake
# Reference: Unfortunately for Ian one of his friends pointed out that he most likely snapped three seals jumping through the water and not the legendary creature.
#
# Prediction: Josh Homme
# Reference: Josh Homme
#
# Prediction: 1. They slow down to appreciate life's little pleasures 2. They exercise 3. They spend money
# Reference: 1. They slow down to appreciate life's little pleasures. 2. They exercise. 3. They spend money on other people. 4. They surround themselves with the right people. 5. They stay positive.
#
# Prediction: ScHoolboy Q finally released his sophomore album this past week
# Reference: ScHoolboy Q I’m not about to be that person that puts his job, his business, his money over his family.
#
# Prediction: "Welcome to the arena, citizens, so grand it can almost hold Donald Trump
# Reference: to poke fun at presumptive GOP presidential nominee Donald Trump
#
# Prediction: paralysed Waist Down
# Reference: Mohammad Shams Aalam Shaikh
#
# Prediction: "illegal immigrant"
# Reference: Illegal Immigrant
#
# Prediction: altruism
# Reference: altruism
#
# Prediction: Beauty Is Everywhere
# Reference: Beauty Is Everywhere
#
# Prediction: "I had not seen or even heard of braces before [coming to America]. I had
# Reference: Pillsbury dough options for a single product type barely fit into one aisle braces To pay rent, you have to use a check corn dogs
#
# Prediction: Doing Long Bouts of Cardio Doing Long Bouts of Cardio Doing Long
# Reference: #1: Doing Long Bouts of Cardio #2: Doing Crunches & Sit-Ups To Get Flat Abs #3: Using Gym Machines #4: Repeating The Same Workouts Over & Over #5: Doing Loooong Workouts
#
# Prediction: Bella Heathcote
# Reference: Max Minghella
#
# Prediction: My Activity page
# Reference: My Activity page
#
# Prediction: A German firm has apologised for producing condoms marked with an offensive message that
# Reference: The contraceptives, ordered by the youth wing of the National Democratic Party (NPD), came in black boxes bearing the slogan "For foreigners and certain Germans"
#
# Prediction: 1. First, your main goal is to find the balance between taking action and taking enough care of
# Reference: 1. First, your main goal is to find the balance between taking action and taking enough care of yourself that you’re actually able to work effectively. 2. On that note, recognize that self-care doesn’t have to be indulgent and superfluous. Think of it as securing your own oxygen mask before you assist others. 3. If you get overwhelmed thinking about what to prioritize, consider where you can actually be most helpful.
#
# Prediction: The metropolitan elite are in for a bit of a shock when they start their inevitable stamped
# Reference: chef/patron Stephen Harris isn’t your average star chef two restaurants in one: a pub with a dining room that also does a tasting menu own salt slipsole in seaweed butter you get a day trip to the seaside into the bargain
#
# Prediction: she was practicing for a lockdown drill at her preschool and what you should do if
# Reference: Wehrman Feeley She was practicing for a lockdown drill at her preschool and what you should do if you are stuck in a bathroom,
#
# Prediction: Richmond, California
# Reference: The power of 'eminent domain' allows governments to seize private property for a public purpose
#
# Prediction: delivery man
# Reference: 6-foot-3, 250-pound former NFL linebacker — now state senator and business owner — Napoleon Harris
#
# Prediction: Iron Man 3/Marvel Studios
# Reference: 15-Year-Old Woman Named Riri Williams
#
# Prediction: high protein, low carb diet help her shed the pounds
# Reference: has lost over 70 pounds
#
# Prediction: positional asphyxiation
# Reference: Babies don’t have the neck muscles to keep their heads upright, so if they are not properly buckled into a rocker or a car seat, their chin can freely fall on their chests and cut off air supply.
#
# Prediction: A "free spirit", a "she lit up a room".
# Reference: I had posted: "Don’t you think it’s a bit soon to fall in love again?"
#
# Prediction: fuschia pink
# Reference: Donald Trump is causing a yarn shortage in the United States, where many Americans just can't get their hands on worsted fuschia pink - because many of the world's knitters are using it to protest against the incoming president.
#
# Prediction: he gets up from bed, where he’s apparently been sleeping all day long.
# Reference: groans and whines
#
# Prediction: I love Asians,’ ‘I’m only attracted to Asians,’ "
# Reference: Being 'really into asians' can be based on offensive stereotypes, some women say.
#
# Prediction: Budweiser airs its Clydesdales commercials several times to make up for
# Reference: tribute to the people who lost their lives in the 9/11 attacks
#
# Prediction: 1. June Kyra Dela Chica, who made the most amazing tribute to Mulan
# Reference: 1. June Kyra Dela Chica, who made the most amazing tribute to Mulan in her high school ID. 2. After being asked by a boy to send a pic of herself in the shower, 16-year-old Reese Herbert sent along this glorious umbrella shower pic. 3. Kris Costello, who took the most extra senior photos ever. 4. The tall teen who had special biz cards made so that he could stop hearing the saaaaame questions over and over again. 5. This Dublin, Ohio, teen who couldn’t "trust
#
# Prediction: food labels confusion
# Reference: The nation's food industry announced plans to cut through the food label confusion with easier to understand language
#
# Prediction: feature phones
# Reference: price battery life innovative hardware and services mobile-payment systems that require nothing more than text-messaging
#
# Prediction: Kim Kardashian Checking Her Makeup
# Reference: Kim Kardashian Checking Her Makeup
#
# Prediction: The moment she told me what she was doing I broke down. She was practicing for a
# Reference: She was practicing for a lockdown drill at her preschool and what you should do if you are stuck in a bathroom
#
# Prediction: she's gotten an Instagram account
# Reference: Queen Rania Of Jordan
#
# Prediction: Kundan Lal Gujral
# Reference: Kundan Lal Gujral
#
# Prediction: "Cabot," after Banksy, after the infamous, as-ye
# Reference: Banksy had come to the school and painted a 14-foot mural to thank the kids.
#
# Prediction: monochromatic look
# Reference: Queen Maxima
#
# Prediction: Jaden Smith is dead
# Reference: death hoax
#
# Prediction: she’s really keen to play the role of Kitana
# Reference: she kind of likes the blades
#
# Prediction: The suspense and tension in The Thing comes from the fact that the titular monster can
# Reference: a little gleam in the eye of the actor. It gives life.
#
# Prediction: footwear
# Reference: good quality boots
#
# Prediction: lemons
# Reference: lemons
#
# Prediction: Telcos Spark and Vodafone
# Reference: Spark
#
# Prediction: green one-piece
# Reference: look at the side and you'll spot a few statement-making cutouts
#
# Prediction: The last line you’ve read (at the bottom of the page) should jump up to
# Reference: The Wall Street Journal USA Today The New Yorker Variety Slate
#
# Prediction: Neanderthals may have given Neanderthals genital herpes
# Reference: When modern humans met Neanderthals in Europe
#
# Prediction: post-shower selfie
# Reference: Makeup-free and wrapped in a towel
#
# Prediction: "Sure!'
# Reference: This Santa wasn’t ready for this role. A terminally ill child died in his arms
#
# Prediction: A West Point cadet was caught using her smartphone during a march to the military academy
# Reference: It is unclear what the cadet was doing on her phone, but the incident is attracting criticism on social media from those who say she lacks discipline and respect.
#
# Prediction: cocaine
# Reference: I got a divorce from my husband, and I started hanging out out with this guy I was sort of madly in love with.
#
# Prediction: bimanual pelvic exam
# Reference: bimanual pelvic exam.
#
# Prediction: brexit how the hell are you gonna be mr. brex
# Reference: used the reference to imply that he would win the U.S. election despite a general consensus of polls showing that he trails his rival significantly
#
# Prediction: London Bridge is down
# Reference: London Bridge is down
#
# Prediction: Wal-Mart (WMT) to sell her organic and natural deodorant products because
# Reference: Primal Pit Paste
#
# Prediction: Track their colleagues
# Reference: Men are actually tracking their colleagues’ periods with an app
#
# Prediction: eschew discs for good old fashioned cartridges
# Reference: Nintendo’s core client base is families – especially those with small children. Children are notorious for ruining disks
#
# Prediction: One theory purported by Portuguese police suggested that "Madeleine had been killed by her
# Reference: In March 2016, Madeleine's case took a strange turn when an ad taken out in a Paraguayan newspaper claimed that Madeleine had been seen in Paraguay, reigniting rumors that the child was still alive. However, Mirror reports that this theory has since been debunked.
#
# Prediction: food
# Reference: emaciated dog
#
# Prediction: 1. Prioritizing paying student loans over saving for retirement 2. Using a credit score above
# Reference: 1. Prioritizing paying student loans over saving for retirement. 2. Investing too conservatively 3. Turning to credit cards to afford luxuries. 4. Living in a fancy place with no financial foundation. 5. Feeling bad about delaying adulting.
#
# Prediction: namely that they don’t exist.
# Reference: the push on kids content comes from the role ads play on many of these platforms: namely that they don’t exist
#
# Prediction: Brenton Thwaites
# Reference: Australian actor Brenton Thwaites
#
# Prediction: Chris Brown, of course. "Why I gotta have the plumbers butt/c
# Reference: "This n----a KANYE CRAZY, talented, but crazy." Anna Wintour and Caitlyn Jenner's reps had no comment, and nobody else has spoken out yet
#
# Prediction: A Roomba runs over dog poop, stop it immediately and do not let it
# Reference: products demand too much from their users while providing too little value in return
#
# Prediction: Olivia Wilde
# Reference: Olivia Wilde
#
# Prediction: clench the muscles in your lower body to push blood back into your upper body
# Reference: clench the muscles in your lower body to push blood back into your upper body
#
# Prediction: Netflix has only ever canceled three shows: Hemlock Grove, Lilyham
# Reference: end a show
#
# Prediction: Hillary Clinton
# Reference: Trump
#
# Prediction: The Godfather, and against all odds seems as energised as he’
# Reference: 1. Back and forth with Eksman 2. Working with Dizzee 3. Sorry Sorry Pardon What 4. Step Three Freestyle 5. Bring Them All/Holy Grime ft Devlin
#
# Prediction: £1 billion dollars
# Reference: £1 billion
#
# Prediction: massive network of tunnels
# Reference: under the Roman Emperor Hadrian's Villa in Tivoli, Italy.
#
# Prediction: $420,000
# Reference: roughly $420,000
#
# Prediction: Bone Broth
# Reference: bone broth
#
# Prediction: GTA 6 will feature a main character – or characters – that players will be
# Reference: This is a work of fiction and part of our weekly Satire column
#
# Prediction: TMZ
# Reference: 48 shows per year raking in $310,000 per show
#
# Prediction: Mount Sourabaya
# Reference: Mount Sourabaya
#
# Prediction: Probably when I’m home with my baby, just spending time with her and being in
# Reference: anything having to do with eyeballs
#
# Prediction: Kentucky Fried Chicken
# Reference: KFC had an amazing marketing strategy
#
# Prediction: may reduce the ability to feel empathy for others
# Reference: may reduce the ability to feel empathy for others
#
# Prediction: lack of humility and an over sense of self-promotion
# Reference: lack of humility and an over sense of self-promotion
#
# Prediction: camping
# Reference: spot of camping
#
# Prediction: not intelligence or talent
# Reference: ability to delay gratification
#
# Prediction: The Biggest Loser Revealed
# Reference: only a temporary fix
#
# Prediction: Belgium
# Reference: Belgium
#
# Prediction: A Texas father who discovered a man raping his five-year-old daughter and
# Reference: will not be charged
#
# Prediction: The presence of others
# Reference: presence of other people
#
# Prediction: its convenience
# Reference: cereal was an inconvenient breakfast choice because they had to clean up after eating it
#
# Prediction: The W...
# Reference: increasing the minimum wage
#
# Prediction: The All New Captain Underpants Extra-Crunchy Book o' Fun 2
# Reference: Captain Underpants Extra-Crunchy Book o' Fun 2
#
# Prediction: number of blades of a fan
# Reference: Being lighter, the fan operates at a higher speed and is also energy efficient.
#
# Prediction: Kris Bryant
# Reference: Kris Bryant
#
# Prediction: 1. Forest XPlorer (Android/iOS, free) 2. ViewR
# Reference: 1. Forest XPlorer (Android/iOS, free) 2. ViewRanger (Android/iOS, free + IAP) 3. The Gruffalo Spotter (Android/iOS, free) 4. Blue Plaques of London (Android/iOS, free) 5. Hover (Android/iOS, free)
#
# Prediction: Debbie Harry
# Reference: Blondie concerns over civil rights abuses in Russia
#
# Prediction: a low-cut top, a blazer and patent leather stiletto
# Reference: all-black ensemble, including some tight denim, a low-cut top, a blazer and patent leather stiletto pumps
#
# Prediction: a model walking in front of fiery wings
# Reference: smartphone
#
# Prediction: To celebrate Ubisoft’s 30th anniversary, The Ubisoft Club is
# Reference: Ubisoft Club is offering you seven digital PC games
#
# Prediction: creating really, really rich people
# Reference: creating really, really rich people
#
# Prediction: Keywords are descriptors of skills and attributes that industry insiders typically use
# Reference: Keywords
#
# Prediction: Relationships
# Reference: relationships
#
# Prediction: no plan for a fourth Iron Man
# Reference: "There isn’t one in the pipe. No, there’s no plan for a fourth Iron Man."
#
# Prediction: Colombia
# Reference: Colombia
#
# Prediction: love, Actually. Whilst love actually may be all around, for most of us it doesn
# Reference: Love The Holiday Elf The Grinch
#
# Prediction: twins
# Reference: twins
#
# Prediction: Facebook says it plans to marginalize what it considers to be "clickbait" news
# Reference: certain types of headlines would be classified as clickbait, those that "withhold or distort information." Those stories will then appear less frequently in users’ feeds
#
# Prediction: The clocks go back an hour in 2017 on October 30.
# Reference: 100th anniversary
#
# Prediction: Tennessee
# Reference: Tennessee
#
# Prediction: A healthy 20-year-old woman was running on a beach with friends when she fell
# Reference: commotio cordis
#
# Prediction: Tesla's car line to be the definition of sexy — literally.
# Reference: The Model S, Model X, and upcoming Model 3 are all part of a quest for the car line to spell SEXY or S3XY Tesla wants to produce a mini bus and semitruck in the future. Musk is a huge fan of placing Easter eggs in Tesla cars, like the one that lets you "drive" down Rainbow Road — like in Mario Kart! Musk is clearly a fan of rainbows, because pressing the button on Tesla's charge handle will make the port flash in rainbow colors. Model S owners can hold down the "T" button to bring up the
#
# Prediction: the Core
# Reference: the Core
#
# Prediction: Thursday, September 8
# Reference: September 8.
#
# Prediction: "Judas!" yelled someone in the crowd, referencing a trait
# Reference: an electric guitar
#
# Prediction: loneliness
# Reference: loneliness
#
# Prediction: CONQUER POTTY TRAINING WITH TREATS (AND DON'T
# Reference: CONQUER POTTY TRAINING WITH TREATS LAUGHTER IS THE BEST MEDICINE TRICKS FOR GETTING THEM TO SLEEP IT'S OKAY TO USE BRIBES EVERY ONCE IN A WHILE CELEBRATE ACTS OF KINDNESS
#
# Prediction: $353 for a round-trip flight to Stockholm $325 with Norwegian
# Reference: Fly with budget airlines Get a travel credit card Sign up for an email subscription list Don’t hesitate to buy when there’s a ridiculously low one-way flight Utilize fare finder calendars
#
# Prediction: Singapore
# Reference: we can fit all 7.4 billion of us into a city the size of Texas, Oklahoma, and Louisiana added together
#
# Prediction: Elliott Smith's "Between the Bars"
# Reference: Elliott Smith's 'Between The Bars'
#
# Prediction: Dormammu
# Reference: However, if this document is the real deal, this means that Dormammu has been secretly been set up as major threat in Doctor Strange.
#
# Prediction: second cub
# Reference: gave birth to a second cub
#
# Prediction: Cory Booker (D-N.J.) learned he was headed to Washington
# Reference: the second black member currently in the U.S. Senate
#
# Prediction: Yahoo
# Reference: Yahoo
#
# Prediction: The crypts. Where they keep the dead. Like Jon's birth mother, Ly
# Reference: The crypts
#
# Prediction: 1. Any Member State may decide to withdraw from the Union in accordance with its own constitutional requirements
# Reference: The policy of the government (if not of all of its ministers) is to remain in the EU. The UK government may thereby seek to put off the Article 50 notification, regardless of political pressure and conventional wisdom
#
# Prediction: a diet that doesn't have a negative impact on any number of ailments, including
# Reference: After a week, though, I was down two pounds
#
# Prediction: "Pain & Gain."
# Reference: "Pain & Gain."
#
# Prediction: flexible touchscreen
# Reference: device, produced by Moxi Group initially will only have black-and-white displays
#
# Prediction: rounded squares for iOS icons
# Reference: Steve Jobs had been a big fan of shapes with subtle rounded corners
#
# Prediction: raising money for a good cause
# Reference: Entering a charity run in memory of a loved one or a bicycle ride for a worthy cause has pushed many couch potatoes from their sedentary lifestyle on to the path of fitness.
#
# Prediction: The New England Patriots stunned the St. Louis Rams to win the first Super Bowl of
# Reference: the Patriots
#
# Prediction: High IQ Higher IQ Higher IQ Blue, green or hazel eyes Red
# Reference: Higher IQ Blue, green or hazel eyes Reddish hair Piercing eyes Empathic qualities
#
# Prediction: Vietnam
# Reference: Saudi Arabia
#
# Prediction: Baltie Larson
# Reference: Emilia Clarke
#
# Prediction: Molly Sings is the most heartwarming part of this performance is the reaction coming
# Reference: "You had control. When I turned around, you had confidence. I’m a girl, you’re a girl. I have four kids that are girls. So if I was you, from girl-to-girl, I would go with me."
#
# Prediction: 28 and 32
# Reference: Age 28 through 32
#
# Prediction: coconut milk
# Reference: coconut milk
#
# Prediction: "I am not running for president,"
# Reference: "I am determined -- fiercely determined -- to do everything I can to help us once again be the America that creates opportunities for anyone who works hard and plays by the rules.
#
# Prediction: "Prism."
# Reference: record for the most No. 1 songs in the history of Billboard's Pop Songs radio airplay chart
#
# Prediction: One waitress in Herndon, Va. got something extra and then some when a
# Reference: $1,200
#
# Prediction: Xylitol
# Reference: Xylitol
#
# Prediction: Shae-Lee Shackleford 25-year-old Lana Kington 27-
# Reference: sexy lipsyncing
#
# Prediction: Eritrea
# Reference: Eritrea
#
# Prediction: 1. Going to get a bikini wax while on your period and them accidentally catching
# Reference: 1. Going to get a bikini wax while on your period and them accidentally catching your tampon string on the wax strip and yanking it out. 2. Watching Netflix while in the bath but being scared that some pervy man has hacked into your webcam and can see you. 3. Someone going to pick something off your chin and fearing that it may just be a hair they’re about to pull out. 4. Washing your hands next to someone in the bathroom but fearing that you’re not washing them well enough so overwashing them just to make
#
# Prediction: "If you are going to have him on, he’s a politician,"
# Reference: hold his feet to the fire
#
# Prediction: Peter Alliss a former professional golfer turned commentator, was a bit distracted
# Reference: Peter Alliss Sergio Garcia
#
# Prediction: Sydney
# Reference: Sydney
#
# Prediction: No crunch? That would ruin my...minute? Two minutes?
# Reference: a life-long supply of Kit Kat
#
# Prediction: BLUE smoothie bowls are 100 percent natural  made with homemade food dye
# Reference: homemade dye cooked down from red cabbages
#
# Prediction: Vince Gill "I came out to see what hatred really looked like in the face,"
# Reference: Vince Gill "You know what else [Jesus Christ] said? He said a lot of stuff about forgiveness, about grace. You guys don't have any of that."
#
# Prediction: Lindsay Lohan
# Reference: Duran Duran
#
# Prediction: Wal-Mart
# Reference: Asda’s La Moneda Reserva Malbec
#
# Prediction: Linda Rodin, Model And Skincare Guru, On Aging
# Reference: Linda Rodin face oil, Olio Lusso
#
# Prediction: You can lay claim to one glazed donut, free of charge.
# Reference: If you are one of the first 1,000 customers at a Krispy Kreme donut shop on Feb. 24, you can lay claim to one glazed donut
#
# Prediction: Sean Hayes
# Reference: But Hayes will not be among as big a crowd of gay leading characters on broadcast television as he would have been had his show premiered last year.
#
# Prediction: a single manufacturer of pizza savers could be raking in as much as $8
# Reference: pizza saver
#
# Prediction: a flexible work schedule will make their workday more productive
# Reference: Flexible work hours DO make employees more productive
#
# Prediction: I sat in the Iron Throne, looking down at all of my constituents
# Reference: It doesn't seem as thrilling until you sit down. Then you feel the power of those 1,000 swords beneath you, and you realize why Cersei set fire to the Great Sept to have it. My arms rested on the hilts of the surrendered swords, and the power rushed to my head. I felt like royalty
#
# Prediction: ATM fees A simple solution: If your bank's logo isn't on the
# Reference: ATM fees Late fees Underused subscriptions Buying lunch every day Bottled water
#
# Prediction: Moon Garden
# Reference: NASA
#
# Prediction: Yonat Zwebner
# Reference: Yonat Zwebner, a new mother with especially good reason to agonize: Her own research suggests that people come to look like their names
#
# Prediction: 1. The 1972-73 Islanders, 12-60-6. 2. The 1972-73 Islanders
# Reference: 1. The 1983-88 Columbia football team. 2. The 2014-15 Knicks, 5-36. 3. The 1962 Mets, 40-120. 4. The 2003-04 St. John’s basketball team, 6-21 (which became 2-21). 5. The 1996 Jets, 1-15.
#
# Prediction: 40% of all home sales in July were purchased by buyers with cash upfront
# Reference: In July, almost half of all home sales were all-cash deals
#
# Prediction: Jon Stewart "I scroll around, but when I look at the internet, I feel the same
# Reference: BuzzFeed headlines pay off particularly well because they actually make fairly small promises and then overdeliver
#
# Prediction: intermittent fasting
# Reference: intermittent fasting
#
# Prediction: 1. Canned Tomatoes 2. Soda Pop 3. Soy 4. Soy
# Reference: 1. Canned Tomatoes 2. Soda Pop 3. Farmed Salmon 4. Processed Meats 5. Microwave Popcorn
#
# Prediction: Not: Would I do it on some theoretical day in the future?
# Reference: Would I do it tomorrow?
#
# Prediction: "Views" has topped the Billboard 200 album chart for its ninth straight week
# Reference: streaming
#
# Prediction: raw potato juice
# Reference: Raw potatoes
#
# Prediction: A GROUP of hardcore Christians has claimed a solar eclipse due to hit the UK
# Reference: Christian group claim scripture suggests August 21 will bring on an apocalypse
#
# Prediction: Smash Mouth's "All Star" whether anyone wants to hear it or not —
# Reference: At first glance, it appears the guy in this video going viral on Reddit is going to sing Smash Mouth's "All Star" whether anyone wants to hear it or not — even if the sound system is blasting John Lennon's "Imagine."
#
# Prediction: $1.3 billion
# Reference: $1.3 billion
#
# Prediction: Eventually, this often occurs right about the time investors fully embrace yesterday's news and are
# Reference: avoid using past performance as an excuse to abandon diversification and concentrate their portfolios on recent winners
#
# Prediction: Rhode Island 1. Manchester, N.H. 2. New Hampshire 3. Richmond, Va. 4. Louisiana
# Reference: best state and city for small business
#
# Prediction: 1. Panera 2. Taco Bell 3. Starbucks 4. Starbucks 5. Starbucks
# Reference: 1. Panera Pasta 2. Taco Bell Steak and Beans 3. Starbucks ‘Secret Menu’ Items 4. Your Local Movie Theater Popcorn 8. KFC BBQ Sandwiches
#
# Prediction: "no."
# Reference: "no."
#
# Prediction: Regularly wash and thoroughly dry your balls in the morning and keep them dry throughout the day.
# Reference: Regularly wash and thoroughly dry your balls keep them dry throughout the day keep your balls unconstricted use an antifungal powder gel
#
# Prediction: "Look Into My Eyes."
# Reference: "Blacc Hollywood,"
#
# Prediction: will not support the older save files in present gen consoles
# Reference: will not support the older save files
#
# Prediction: criminals-turned-terrorist
# Reference: illegal firearms that may be increasingly easy for suspected terror networks to obtain
#
# Prediction: 1. T-Mobile Las Vegas 2. T-Mobile Arena 3. T-Mobile Las Vegas 4. T
# Reference: 5. T-Mobile Las Vegas 4. Las Vegas Ice Rebels 3. Las Vegas Outlaws 2. Las Vegas Aces 1. Las Vegas Wranglers
#
# Prediction: Alex Newell
# Reference: Alex Newell "Geography Club"
#
# Prediction: Alfred Hitchcock
# Reference: Alfred Hitchcock Fell Victim To Beatlemania
#
# Prediction: mummified remains
# Reference: The mummy’s shoes feature colored stripes which, as many commenters pointed out, look strangely similar to the Adidas logo
#
# Prediction: That Cognac was a place in France, and that’s where they make the product
# Reference: Nasir "Nas" Jones Excitement
#
# Prediction: Torrey Pines State Natural Reserve
# Reference: Tree groves are a fairly uncommon sight along the southern California coast, so when early Spanish explorers stumbled upon Mother Nature's magical pines, the area was dubbed Punto de Los Arboles, which literally translates to "Point of Trees."
#
# Prediction: Nest thermostats
# Reference: Industrial and commercial uses
#
# Prediction: Jackson, Mississippi
# Reference: Jackson, Mississippi
#
# Prediction: Galbani string cheese
# Reference: "The 3 types of full fat cheese each have a different 'boy' string cheese cartoon character, but the low fat cheese character has been drawn as a girl,"
#
# Prediction: Belgium
# Reference: Belgian colony of Leopoldville
#
# Prediction: Etruscan sarcophagus
# Reference: drab free port zone near the Geneva city center
#
# Prediction: Pennsylvania
# Reference: Pennsylvania
#
# Prediction: girl
# Reference: girl
#
# Prediction: Kareena Kapoor
# Reference: Kareena Kapoor
#
# Prediction: "The Life of Pablo"
# Reference: Kanye West gave Tidal a big boost this weekend by releasing his latest album "The Life of Pablo" exclusively on the Jay Z-owned streaming service.
#
# Prediction: BBM is still very much a thing, and the QNX platform is being expanded
# Reference: Our financial foundation is strong, and our pivot to software is taking hold," said Chen.
#
# Prediction: 12345678,
# Reference: 123456 multiple variations of 'password,' 121212 qwerty login
#
# Prediction: klittra
# Reference: "klittra"
#
# Prediction: Seagulls are what biologists call kleptoparasites, animals that
# Reference: Gulls are what's known as "opportunistic kleptoparasites," meaning they don't derive 100 percent of their diets from heist but rather just steal when the opportunity arises. And a big vat of tikka masala is an opportunity no gull can afford to miss.
#
# Prediction: Irula tribe
# Reference: Eranna
#
# Prediction: By masking its bikes as TVs, VanMoof, a Dutch manufacturer that export
# Reference: damages reduced by 70-80 per cent
#
# Prediction: Bill Carter
# Reference: Bill Carter
#
# Prediction: San Francisco and Los Angeles
# Reference: San Francisco Los Angeles
#
# Prediction: Spicy Buffalo sauce
# Reference: Spicy Buffalo sauce
#
# Prediction: One police officer braved the wrath of angry citizens to defend a pro-
# Reference: braved the wrath of angry citizens to defend a pro-coup soldier
#
# Prediction: Ballistic: Ecks vs. Sever (2002)
# Reference: Ballistic: Ecks vs. Sever (2002)
#
# Prediction: 1. Take A Hike 2. Grow Your Idea 3. Don't Use It 4. Don't
# Reference: 1. Take A Hike 2. Grow Your Idea 3. Get Unlost When I feel like I'm lost, I write things down. 4. Value It You have to value what's around you. 5. I'm Done With... I'm done with negativity.
#
# Prediction: shopping for the travelers
# Reference: WestJet employees went shopping for the travelers. These real-life elves checked items off the list and certainly checked it twice to make sure every passenger got what he or she wished for
#
# Prediction: platinum
# Reference: platinum
#
# Prediction: Zero Zero Zero
# Reference: cocaine
#
# Prediction: UConn
# Reference: University of Connecticut
#
# Prediction: these so called "schemes" are actually creating opportunities for millions to begin their own businesses from
# Reference: These so called "schemes" are actually creating opportunities for millions to begin their own businesses from home.
#
# Prediction: "thank you"
# Reference: "thank you"
#
# Prediction: Patrick Fugit
# Reference: Bandy Swiftpet
#
# Prediction: 39.6 percent
# Reference: payroll taxes
#
# Prediction: Google Auto LLC
# Reference: Google Auto LLC
#
# Prediction: A couple from Gujarat’s tribal district Dahod has finally opted for a
# Reference: A couple from Gujarat’s tribal district Dahod has finally opted for a family planning operation after conceiving 17 children, which includes 16 daughters and a son.
#
# Prediction: sticky mess
# Reference: three neighborhood squirrels
#
# Prediction: Detroit's infant mortality rate is twice the national average and the highest among large American cities
# Reference: Detroit
#
# Prediction: 1. Goals for creating ISIS 2. Goals for creating ISIS 3. Goals for creating
# Reference: 1. Goals for creating ISIS 2. ISIS consists of mercenaries dressed as jihadists, supplied mostly by the governments of Saudi Arabia, NATO's Turkey and chechens sent by Russia. 3. Part of the ISIS killers were originally trained as guards for extermination camps 4. ISIS parades, beheadings, crucifictions and so on, supposedly taking place in Iraq cities, are in fact filmed in Raqqa, Syria. 5. ISIS controls ZERO major cities in Iraq.
#
# Prediction: a lesbian couple may be featured in the film
# Reference: Lesbian Couple
#
# Prediction: 4. Barbiturates (‘downers’) 5. Nicotine
# Reference: 1. Heroin 2. Alcohol 3. Cocaine 4. Barbiturates (‘downers’) 5. Nicotine
#
# Prediction: In latte terms (including applicable taxes), the U.S. currency is about 10
# Reference: latte Big Mac pizza chicken wings Black cod with miso
#
# Prediction: Colorado
# Reference: Colorado Jared Polis
#
# Prediction: Just the opposite
# Reference: Just the opposite
#
# Prediction: 1. Your relationship difficulties 2. Your detailed financial state -- or financial problems 3. Your legal woes
# Reference: 1. Your relationship difficulties 2. Your detailed financial state -- or financial problems 3. Your legal woes 4. Your health situation, except as it applies to work 5. Your family drama
#
# Prediction: 1. Give them an IOU that you'll make them their fave breakfast whenever they want!
# Reference: 1. Give them an IOU that you'll make them their fave breakfast whenever they want! 2. Offer to snooze their alarm for a week so they get those precious five extra minutes. 3. Defrost their car for them before they go to work. 4. Leave them sweet "notes" around the house. 5. Write them a song and record it.
#
# Prediction: Tesla's entry-level $35,000 Model 3 electric car will be available for preorder on
# Reference: In his tweets, Musk said consumers could begin preorders next month with a $1,000 deposit.
#
# Prediction: The specific blooper features Maslany, as Cosima, talking into
# Reference: The specific blooper features Maslany, as Cosima, talking into a phone and telling the person on the other end that they need to talk to Cosima.
#
# Prediction: thermal cameras
# Reference: thermal camera to take picture of the heat marks from where your fingers have just tapped the screen
#
# Prediction: Jordan Brown he has now issued a statement to the media confirming he had made
# Reference: Jordan Brown has now issued a statement to the media confirming he had made it up, saying, Today I am dismissing my lawsuit against Whole Foods Market. The company did nothing wrong
#
# Prediction: Fasting may provide a more accurate assessment of triglyceride levels, another
# Reference: Current cholesterol testing guidelines in the United States stipulate that fasting before a cholesterol test is "preferred." But repeated studies have found no clinically significant differences between results from cholesterol tests done on a full stomach and those done after fasting.
#
# Prediction: at the start the players will have an option to choose who they want to play as between the
# Reference: Batman series will be launched in this summer third season of The Walking Dead will release in the fall this year
#
# Prediction: At 6'6", the guard had size and ball-handling skill comparable to Magic Johnson
# Reference: return to his hometown of Memphis, Tenn., to, of all things, coach a middle school basketball team
#
# Prediction: abnormal color vision increases
# Reference: rate of abnormal color vision
#
# Prediction: Landa
# Reference: Landa
#
# Prediction: Elizabreth "Mom, why does my name sound like something from The Lord
# Reference: Elizabreth Meldor Aliviyah Mhavrych Beberly
#
# Prediction: 16
# Reference: no laboratory confirmed cases
#
# Prediction: the genets
# Reference: Dog Adopts Baby Genets
#
# Prediction: While the former chooses to keep its movies separate from its various television series, the latter has
# Reference: For Daredevil and company though, the studio has made a point to set the Netflix universe in a world where the events of the MCU take place far outside the scope of our heroes.
#
# Prediction: "It was a lot more ballsy than I would ever normally be."
# Reference: Naomi Watts
#
# Prediction: They're Hunched Over, And Their Necks Are Sore
# Reference: 3,417 texts a month
#
# Prediction: 1. The morning-after pill is a form of emergency contraception that can prevent pregnancy when
# Reference: taking such a high dose of hormones could cause irregular bleeding and mess with your menstrual cycle
#
# Prediction: Northern Ireland
# Reference: "We do not anticipate that the result of the EU Referendum will have any material effect on HBO producing Game Of Thrones,"
#
# Prediction: no. There's no ‘major' difference between the two payment systems.
# Reference: no ‘major' difference
#
# Prediction: fish and chips
# Reference: fish and chips
#
# Prediction: business thing split us apart
# Reference: new manager and new business practices
#
# Prediction: Zosia Mamet
# Reference: Zosia Mamet ASOS
#
# Prediction: No
# Reference: that probably wasn’t a time traveler
#
# Prediction: I accidentally googled "Kimono Dragon" instead of 'seagal
# Reference: ham solo marled dachshund Deli Lovato Kimono Dragon haircats
#
# Prediction: Portland, Maine
# Reference: Portland, Maine
#
# Prediction: Turing Robotic Industries
# Reference: Turing Phone Cadenza
#
# Prediction: Syracuse University
# Reference: Syracuse University
#
# Prediction: Miley Cyrus
# Reference: Taylor Momsen
#
# Prediction: Zhao
# Reference: A man in China has survived an attack which left a nail measuring some six inches lodged in his brain
#
# Prediction: IDI
# Reference: idiCORE
#
# Prediction: The pre-teen squad—Millie Bobby Brown, Caleb McLaughlin
# Reference: food allergies
#
# Prediction: Huma Abedin longtime aide to Hillary Clinton, the Democratic nominee for president,
# Reference: Duffy asked why the alleged Muslim Brotherhood connections to Huma Abedin are not being talked about. Perhaps it’s because they are bogus
#
# Prediction: Washington, D.C.
# Reference: Washington, D.C.
#
# Prediction: You will not stand up. You may leave yourself in the heaviness of your breath
# Reference: You say something like: "Mrs. Booker. I have terrible, terrible news. Ernest died today."
#
# Prediction: President Rodrigo "Rody" Duterte said during his speech on Wednesday that
# Reference: business owners that he will kill them if they continue to practice endo or contractualization
#
# Prediction: Max and Scott
# Reference: the two gentlemen duking it out in front of a cheering crowd are Max and Scott
#
# Prediction: pallet wood in some bigger amount to accomplish sitting about eight to 10 family members in a comfortable
# Reference: DIY home movie theater
#
# Prediction: Dayna Mager sleeping with her baby girl
# Reference: to soothe a crying baby
#
# Prediction: farming simulation video game
# Reference: Farming Simulator17
#
# Prediction: Goldie Hawn
# Reference: Goldie Hawn meditation
#
# Prediction: 500 million people visit the microblogging service each month without logging on
# Reference: The CEO announced plans to roll out an "instant timeline" that lets users see what’s happening on the site without having to first follow people. He also said the company is working on new mobile applications that will simplify the sign-up process.
#
# Prediction: high levels of chemicals such as these are linked with cancer
# Reference: Some studies do appear to have shown that meat that has been burned, fried or barbecued is associated with higher possibilities of certain cancers, but these links are hard to prove for certain.
#
# Prediction: Emporer Palpatine as Rey's grandfather — revealing the truth of
# Reference: Emporer Palpatine as Rey's grandfather
#
# Prediction: Premature balding
# Reference: Premature balding
#
# Prediction: around 1,000 times per year
# Reference: around 1,000 times per year
#
# Prediction: natural moisturizing effects of yogurt, honey and grapes
# Reference: natural moisturizing effects
#
# Prediction: The '57' is placed on the bottle neck as the best spot to tap in order
# Reference: To release Heinz Tomato Ketchup from its glass bottle with extra speed, apply a firm tap to the spot marked '57'
#
# Prediction: £4.
# Reference: £4
#
# Prediction: 1. Stop drinking so much damn juice 2. Try not to sit like you're a cocktail
# Reference: 1. Stop drinking so much damn juice. 2. Try not to sit like you're a cocktail shrimp. 3. Breathe like you're not on the verge of dying 4. Plant a pretty flower 5. Move your body for a bare minimum of 10 minutes a day.
#
# Prediction: $9M
# Reference: $9 million
#
# Prediction: New England New York
# Reference: California Connecticut Iowa Maine Massachusetts
#
# Prediction: Edinora Jiminez of Santa Marta, Colombia, was out picking oranges
# Reference: Luisa Fernanda Urrea breastfeed the baby
#
# Prediction: Hemsworth has quashed a recent report claiming the "Hunger Games
# Reference: The story of Liam Hemsworth and January Jones is entirely fabricated by US Weekly
#
# Prediction: milk chocolate candies
# Reference: M&M's Mega
#
# Prediction: loaded baked potato
# Reference: Add a chunk of Red Leicester cheese to the center. Wrap the outside of the potato with bacon, using toothpicks to hold the pieces in place. Bake at 400° for 30 minutes. Remove the pins and coat the outside of the potato with barbecue sauce. Bake for an additional 10 minutes. Combine sour cream and hot sauce (to taste) in a small bowl. Top the potato with the spicy sour cream mixture and chives (if desired).
#
# Prediction: Americans are drinking less soda
# Reference: drinking less soda
#
# Prediction: Donald Trump
# Reference: Trump
#
# Prediction: nothing
# Reference: nothing
#
# Prediction: no
# Reference: doesn't support downloadable or physical add-ons
#
# Prediction: U.S. Cellular Field
# Reference: Guaranteed Rate Field
#
# Prediction: Justice League
# Reference: 'Justice League.'
#
# Prediction: six miles high
# Reference: six miles
#
# Prediction: A Boston University School of Medicine study found that women who can still give birth naturally after age 33
# Reference: a higher chance of living to extreme old age
#
# Prediction: 19 minutes
# Reference: 19 minutes
#
# Prediction: bobby pins
# Reference: bobby pins
#
# Prediction: Kishore Bhaijyawala
# Reference: Kishore Bhaijyawala
#
# Prediction: Lady Gaga
# Reference: Lady Gaga
#
# Prediction: lighter locks
# Reference: lighter locks
#
# Prediction: Moe's Southwest Grill
# Reference: Moe's Southwest Grill
#
# Prediction: Chris Evans and Matt LeBlanc
# Reference: "as entertaining as ever"
#
# Prediction: they couldn't shoot first time. The players were instructed that they had to take a
# Reference: couldn't shoot first time
#
# Prediction: To avoid battery drain, make sure your computer is plugged in and powered on while charging.
# Reference: if your device is connected to a computer that's turned off or is in sleep or standby mode Too hot Too cold Facebook app iCloud sync
#
# Prediction: Barenaked Ladies
# Reference: Barenaked Ladies 'Blackfish'
#
# Prediction: sticklebacks
# Reference: swim in schools ingrained in their genes
#
# Prediction: The soda and milk react to each other in this way because the phosphoric acid molecules in
# Reference: An hour later, the Coca-Cola and milk form a transparent liquid with what can only be described as chunks of sediment settled on the bottom.
#
# Prediction: two-thirds of Americans are overweight or obese
# Reference: More than half of adults (55 percent) said they don't think they are overweight and aren't making an effort to shed pounds
#
# Prediction: Seoul
# Reference: Seoul, South Korea
#
# Prediction: Chinese poultry processors will be allowed to ship meat to the U.S.
# Reference: China to export its own domestic chickens to the U.S.
#
# Prediction: They're afraid
# Reference: Women have historically been penalized for taking time off for all the reasons cited by men: Parental leave often jeopardizes their position, deprives them of opportunities, and places them at a disadvantage to non-moms.
#
# ...
# Reference: 1. Window Coverings 2. Linens and Towels 3. Upholstery 4. Room-Size Rug 5. Mattress
#
# Prediction: Christian Lunsford
# Reference: she immediately returned the cash to Lunsford.
#
# Prediction: Corfu, Greece beach home
# Reference: Corfu, Greece beach home
#
# Prediction: June 3
# Reference: June 3
#
# Prediction: one BILLION iPhones
# Reference: Apple has sold... wait for it... one BILLION iPhones
#
# Prediction: vibrator
# Reference: vibrator
#
# Prediction: Tinder users are more likely to be looking for a committed relationship than are offline daters
# Reference: findings indicate that Tinder users are more likely to be looking for a committed relationship than are offline daters
#
# Prediction: women's pheromones interact when they are in close proximity, causing
# Reference: They found that the model assuming that patterns would appear by chance was the best model by far.
#
# Prediction: I just don’t have any real reason to be concerned about what’s going on with
# Reference: I don’t know anything about it. I haven’t seen it yet
#
# Prediction: "Busy!"
# Reference: Busy
#
# Prediction: Kim Jong-un threatens US with a 'super-mighty preemptive
# Reference: Kim Jong-un has threatened the US with a 'super-mighty preemptive strike' and warned America: 'Don't mess with us'.
#
# Prediction: The store produced a T-shirt for the holiday that reads "It’s
# Reference: that reads "It’s Father’s Day," but the words "It’s Her Day" appear in bold white letters with the word "really" placed directly above the "her."
#
# Prediction: I would demand what all the other team owners, for some senseless reason, disallow:
# Reference: So not only did Lin and five-man-go basketball have to go, Dolan’s MSG Network has made him disappear in the hope that we’ll forget and continue to regard Anthony as savior-in-still-waiting
#
# Prediction: The TI watch was a feat of technological novelty, but it was neither beautiful nor practical
# Reference: it will succeed because the company has attended to both ends of the spectrum well enough—and can make up for the rest with its outsize consumer base and loyal development partners
#
# Prediction: more flexible approach to work in a number of facets also means that companies are making paid
# Reference: Thankfully, a more flexible approach to work in a number of facets also means that companies are making paid time off more flexible, too. Not only can you avoid the cloak-and-dagger approach to taking a personal day, but companies are seeing a more malleable PTO schedule pay dividends as well, in terms of employee engagement and job satisfaction.
#
# Prediction: What’s the one thing you want to do before you die?
# Reference: What’s the one thing you want to do before you die?
#
# Prediction: Blue
# Reference: blue
#
# Prediction: He's kind of a one-hit wonder
# Reference: He's kind of a one-hit wonder A string of flops He's not really a nerd He'd rather do voice work And web series work
#
# Prediction: electromagnetic brain stimulation can help obese people lose weight, partly by changing the composition of their intestinal bacteria
# Reference: electromagnetic brain stimulation
#
# Prediction: IFITM family of restriction factors
# Reference: small membrane-associated interferon-inducible transmembrane proteins (IFITMs)
#
# Prediction: Natalie and her husband Andrew from Blackpool won £1m on a scratchcard after Andrew randomly
# Reference: a festive trip to Disneyland Paris
#
# Prediction: Hong Kong
# Reference: Hong Kong
#
# Prediction: The site's comeback has been fraught with problems from the get-go. In
# Reference: the Pirate Bay appears to have been replaced in popularity by sites like Kickass.to
#
# Prediction: I am the least qualified person to comment on anyone playing the role of Batman since I so
# Reference: "I am the least qualified person to comment on anyone playing the role of Batman since I so terribly destroyed the part," Clooney said
#
# Prediction: they are attempting (and succeeding) in getting their owners’ attention.
# Reference: First of all, they are attempting (and succeeding) in getting their owners’ attention. Secondly, they bat things around in the apartment because they’re instilled with the predatory instinct to hit something with their paws.
#
# Prediction: "Discovery of the Camp"
# Reference: "Discovery of the Camp"
#
# Prediction: In the Discover function, where members can find popular photos and videos, and in search results
# Reference: Ads
#
# Prediction: Switch to a low-flow showerhead
# Reference: low-flow showerhead
#
# Prediction: seasonal allergies
# Reference: depressed
#
# Prediction: "It came true," Hathaway awkwardly quipped, referencing the iconic song
# Reference: endless string of awkward acceptance speeches
#
# Prediction: Jane Bond
# Reference: Gillian Anderson
#
# Prediction: Michigan
# Reference: to "regulate sexual relationships" and their "unique procreative capacity"
#
# Prediction: traditional farming
# Reference: traditional farming
#
# Prediction: Then, instead of making a single dime, they crated the product of
# Reference: The food and drinks were handed out, free of charge, to all the people who had lined up to donate blood.
#
# Prediction: A former building superintendent working for the Trumps explained that he was told to code any application
# Reference: a man who for more than four decades has been repeatedly associated with racial discrimination or bigoted comments about minorities, some of them made on television for all to see. While any one episode may be ambiguous, what emerges over more than four decades is a narrative arc, a consistent pattern — and I don’t see what else to call it but racism
#
# Prediction: he’ll need more space, though – like the kitchen, where neighbors’ can
# Reference: amid neighbors’ complaints of excessive noise and anti-social behavior
#
# Prediction: Summaries that are way too long; overused résumé jargon; and
# Reference: Summaries that are way too long overused résumé jargon appearing too formal and rigid
#
# Prediction: Washington, D.C.
# Reference: D.C.
#
# Prediction: be the couple that eats off of each other's forks
# Reference: we all have our own preferences
#
# Prediction: 4915963
# Reference: five
#
# Prediction: September 11
# Reference: September 11
#
# Prediction: Money
# Reference: Money
#
# Prediction: $10,000
# Reference: Derrick Walton $10,000 check
#
# Prediction: Clinton’s pneumonia isn’t severe
# Reference: chronic dehydration, exacerbated by her lung problem
#
# Prediction: Farrah Abraham
# Reference: Farrah Abraham
#
# Prediction: "I guess I would do whatever it takes to get things done. You pick up these side
# Reference: bat boy for the Mets
#
# Prediction: "I guess, I like the toaster strudel part. I thought that was pretty
# Reference: the toaster strudel part
#
# Prediction: "Mademoiselle C,"
# Reference: Mademoiselle C
#
# Prediction: #1 Apple inc. #2 Google #3 Google #4 Google 5. Apple
# Reference: #1 Apple inc. #2 Google #3 Microsoft #4 Amazon #5 Facebook
#
# Prediction: The new research from England's University of Surrey determined two types of employees: the flourishing
# Reference: show proof in the courtroom of the negative effects of excessive business travel, which could then lead to a law against it.
#
# Prediction: Singapore
# Reference: best-value city for foreign business
#
# Prediction: North America, including United States, Canada, Mexico, and Greenland, could easily fit
# Reference: Yes! In fact, North America, including United States, Canada, Mexico, and Greenland, could easily fit inside Africa with plenty of room left to add Central America, Argentina, Chile, and Bolivia too.
#
# Prediction: He tells Kevin, "I think it’s possible that you’re looking for my
# Reference: Charlie lets Kevin know that he’s on to his scam, but that he can change his ways. He tells him about the love of the Father, and the saving power of Jesus. He actually gets Kevin to pray the "Sinner’s Prayer."
#
# Prediction: daughter
# Reference: triplets
#
# Prediction: Tesla said the Model S travels at a maximum speed of 1.06 mph while in
# Reference: Jared Overton
#
# Prediction: Netherlands
# Reference: Netherlands
#
# Prediction: the WEATHER
# Reference: so we could get some grim grey weather even in the sunnier places that we shoot.
#
# Prediction: Hawaii
# Reference: Hawaii
#
# Prediction: not only did the Note 7 withstand over 23 hours of being fully submerged in ice
# Reference: managed to get away from the improvised accident without a single scratch
#
# Prediction: BCS Team on the Difficulties of Making a Prequel -- Vulture
# Reference: [Jennifer Bryan] hates them.
#
# Prediction: Northwestern University
# Reference: Northwestern University's Medill School of Journalism
#
# Prediction: "Fuck you".
# Reference: Fuck you
#
# Prediction: I finally reached a breaking point in her early thirties when she realized that
# Reference: "The turning point was hearing from Alden [one of the men she had slept with]. He sent me an e-mail, out of the blue, several months after the project had come to an end. Before long, we were having sex again. Being with him was exquisite. After reconnecting with Alden and falling deeply in love with him, there was no going back."
#
# Prediction: 12.9-inches
# Reference: Microsoft
#
# Prediction: Most people said they would like to live in a world where their car decides to save
# Reference: But if it were their own car, survey takers came to a very different conclusion: Passengers’ lives should take priority over those of pedestrians.
#
# Prediction: Ugg boots
# Reference: Ugg boots
#
# Prediction: "It changes things," Dr. Angelou says. "I know for sure that loves
# Reference: loves saves me and that it is here to save us all
#
# Prediction: first, the L is the inductance second, there is the negative sign third, this
# Reference: The direction of this electric field will make a change in electric potential that acts like a battery.
#
# Prediction: 1. Social connections make us happier and healthier while loneliness kills 2. Having a good life
# Reference: feeling connected to the people around you
#
# Prediction: Tiramisu Latte
# Reference: Tiramisu Latte
#
# Prediction: "mine is bigger".
# Reference: She replied to him with a series of photos of penises.
#
# Prediction: The images show a foreign man and woman walking alongside uniformed officers on the island of
# Reference: Last week photos surfaced of two unidentified Western tourists being paraded around an Indonesian island in a "walk of shame" for alleged theft.
#
# Prediction: Malala Yousafzai
# Reference: Malala Yousafzai
#
# Prediction: homework help or hinder kids
# Reference: Even though some cultures may normalize long periods of studying for elementary age children, there is no evidence to support that this level of homework has clear academic benefits. Also, when parents and children conflict over homework, and strong negative emotions are created, homework can actually have a negative association with academic achievement.
#
# Prediction: Randy Jackson
# Reference: Harry Connick Jr. Jennifer Lopez Keith Urban
#
# Prediction: Fred Armisen
# Reference: Fred Armisen
#
# Prediction: Lithuania
# Reference: Lithuania
#
# Prediction: Many of the risk factors seem baked into the cake at birth.
# Reference: not smoking cigarettes not being obese performing physical activity at least once a week having a healthful diet pattern
#
# Prediction: Susan Boyle
# Reference: As to who is up for the role, Boyle revealed, "I’d like someone to play me. Probably Meryl Streep -- I understand she has been approached."
#
# Prediction: A man in Florida told police he killed his wife because she was in poor health and they
# Reference: A man in Florida told police he killed his wife because she was in poor health and they could no longer afford the medications necessary for her care
#
# Prediction: Mary Shelley by Alfred Clint, 1802 Mary's father may have killed to
# Reference: Shelley's romances led her father to disown her Mary's father may have killed to save his daughter's reputation Shelley, however, says that Frankenstein came to her as she slept
#
# Prediction: ‘First sleep’ and ‘second sleep’
# Reference: Most individuals awakened shortly past midnight to an hour or so of consciousness, in which they meditated, they conversed and made love
#
# Prediction: bring autonomous driving to urbanites who don't own cars — and don't want
# Reference: Car-less city dwellers are already quite well served by good old-fashioned, human-driven taxis
#
# Prediction: Corsica
# Reference: Corsica Pfalz Mt. Etna Hawke’s Bay Yarra Valley
#
# Prediction: El Nio, which is associated with warmer sea surface temperatures in the eastern Pacific Ocean
# Reference: warmer sea surface temperatures in the eastern Pacific Ocean
#
# Prediction: she's perfectly fine with it
# Reference: Julie Andrews is a fan of Emily Blunt's body of work, and she's completely on board with the idea.
#
# Prediction: Anna Victoria makeup-free "casual, non-posing, non-done up
# Reference: fitness star Anna Victoria on Instagram posting one casual, non-posing, non-done up photo
#
# Prediction: The Piano Guys made it their business to play the summer anthem of the Democratic National Convention
# Reference: The Piano Guys play the summer anthem of the Democratic National Convention and a de facto theme of the Hillary campaign, Rachel Platten's empowering "Fight Song."
#
# Prediction: They're cheap. You can get a really great Chromebook for around $200, or
# Reference: cheap versatile perfect if you use Google services
#
# Prediction: Cheyenne Jackson
# Reference: Cheyenne Jackson
#
# Prediction: howling
# Reference: howling
#
# Prediction: Cornell University
# Reference: Elizabeth Garrett will become the first female president of Cornell University, the Ivy League institution announced Tuesday.
#
# Prediction: "done" is better than perfect. It’s a snowball effect. "
# Reference: Saying the word done can help you get more accomplished on your to-do list.
#
# Prediction: Carbonated water is Carbonated water is a form of carbonated water that contains a
# Reference: plain sparkling water appears to pose little risk to dental health may benefit digestive health in several ways Carbonated water appeared to have no effect on bone health Carbonated water may have beneficial effects on cholesterol, inflammation and blood sugar There is currently no evidence that carbonated or sparkling water is bad for you.
#
# Prediction: Crispy Chicken Chips
# Reference: Crispy Chicken Chips
#
# Prediction: engineers Glen Dash and Egyptologist Mark Lehner looked for the original edges to the
# Reference: doesn’t have a perfectly square base, with one particularly lopsided west-facing edge
#
# Prediction: beheadings impalement smoking
# Reference: beheadings impalement smoking
#
# Prediction: To: Ted Miller Hi Ted Miller Hi Kieren, Just wondering if there is going to
# Reference: The truth though is that large tech companies, especially in Silicon Valley, often use access to their events and their executives as a way to force positive coverage of themselves. If you write one bad thing about them, they threaten to stop talking to you. If you ignore the warnings, they blacklist you.
#
# Prediction: The leader of the Islamic State contingent, flanked by several guards with AK-
# Reference: "The ISIS thug who was about to decapitate the father was shot in the head and collapsed," the eyewitness said. "Everyone just stared in confusion. "The sniper then dispatched the two henchmen with single shots — three kills with three bullets. It was a good day’s work."
#
# Prediction: ‘All Along the Watchtower.’
# Reference: ‘All Along the Watchtower.’ The Jimi Hendrix cover
#
# Prediction: how to shave your balls
# Reference: 1. Catch it on a good day. 2. Smooth it out. 3. Lather as you would your face. 4. Finally, shave.
#
# Prediction: full "blood moon" will be visible in the United States and Canada early Wednesday morning, with
# Reference: It will be visible in the United States and Canada early Wednesday morning The full eclipse will start at 6:25 a.m. EDT and last until 7:24 a.m
#
# Prediction: Tami Erin
# Reference: Tami Erin
#
# Prediction: spritz perfume directly onto your skin
# Reference: Celery
#
# Saved predictions, references to /kaggle/working/predictions_references.json

# %%
# !pip install bert_score nltk
# !pip install evaluate

import evaluate

import nltk
from nltk.translate.bleu_score import corpus_bleu, SmoothingFunction
from bert_score import score

# Calculate BERTScore
def calculate_bertscore(predictions, references, lang="en"):
    P, R, F1 = score(predictions, references, lang=lang)
    avg_bertscore = {
        "precision": P.mean().item(),
        "recall": R.mean().item(),
        "f1": F1.mean().item()
    }
    return avg_bertscore

# Function to calculate BLEU-4
def calculate_bleu(predictions, references):
    smoothie = SmoothingFunction().method4  # To handle cases where n-grams may not be present
    bleu_score = corpus_bleu(references, predictions, weights=(0.25, 0.25, 0.25, 0.25), smoothing_function=smoothie)
    return bleu_score

# Function to calculate METEOR
def calculate_meteor(predictions, references):
    # Load METEOR from Hugging Face's evaluate library
    meteor = evaluate.load("meteor")
    # Evaluate with meteor by passing predictions and references
    meteor_result = meteor.compute(predictions=predictions, references=[[ref] for ref in references])
    avg_meteor_score = meteor_result["meteor"]
    return avg_meteor_score
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting bert_score
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (3.2.4)
# Requirement already satisfied: torch>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from bert_score) (2.4.0)
# Requirement already satisfied: pandas>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from bert_score) (2.2.2)
# Requirement already satisfied: transformers>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from bert_score) (4.45.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from bert_score) (1.26.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from bert_score) (2.32.3)
# Requirement already satisfied: tqdm>=4.31.1 in /opt/conda/lib/python3.10/site-packages (from bert_score) (4.66.4)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from bert_score) (3.7.5)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from bert_score) (21.3)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from nltk) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.9->bert_score) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.0.1->bert_score) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.0.1->bert_score) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.0.1->bert_score) (2024.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (2024.6.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /opt/conda/lib/python3.10/site-packages (from transformers>=3.0.0->bert_score) (0.25.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=3.0.0->bert_score) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers>=3.0.0->bert_score) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=3.0.0->bert_score) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /opt/conda/lib/python3.10/site-packages (from transformers>=3.0.0->bert_score) (0.20.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->bert_score) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->bert_score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->bert_score) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->bert_score) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->bert_score) (10.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->bert_score) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->bert_score) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->bert_score) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->bert_score) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.0.0->bert_score) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.0.0->bert_score) (1.3.0)
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 1.7 MB/s eta 0:00:00
# Installing collected packages: bert_score
# Successfully installed bert_score-0.3.13
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: evaluate in /opt/conda/lib/python3.10/site-packages (0.4.3)
# Requirement already satisfied: datasets>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from evaluate) (3.0.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from evaluate) (1.26.4)
# Requirement already satisfied: dill in /opt/conda/lib/python3.10/site-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.10/site-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /opt/conda/lib/python3.10/site-packages (from evaluate) (4.66.4)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from evaluate) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.6.1)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from evaluate) (0.25.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from evaluate) (21.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate) (3.15.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate) (16.1.0)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate) (3.9.5)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.7.0->evaluate) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->evaluate) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->evaluate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->evaluate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->evaluate) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->evaluate) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)

# %%
# Calculate BERTScore
bertscore_results = calculate_bertscore(predictions, references)

# Calculate BLEU-4
bleu_score = calculate_bleu(predictions, references)

# Calculate METEOR
# meteor_score = calculate_meteor(predictions, references)

# Display all results
print(f"TestLoss: {test_loss}")
print(f"BERTScore: {bertscore_results}")
print(f"BLEU-4 Score: {bleu_score}")
# print(f"METEOR Score: {meteor_score}")
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# TestLoss: 0.20288528645038606
# BERTScore: {'precision': 0.8893628716468811, 'recall': 0.8777963519096375, 'f1': 0.8830023407936096}
# BLEU-4 Score: 0.3070390288132313

# %% [markdown]
# # **Post-Hoc Ensemble**

# %%
from transformers import set_seed

# Post-Hoc Ensembling (Section 5.2)
ensemble_seeds = [13, 45, 99, 137, 2023]
all_predictions = []

for seed in ensemble_seeds:
    set_seed(seed)
    model = AutoModelForSeq2SeqLM.from_pretrained(model_checkpoint).to('cuda' if torch.cuda.is_available() else 'cpu')
    
    args = Seq2SeqTrainingArguments(
        f"{model_name}-finedtuned-qa", 
        evaluation_strategy = "epoch", 
        learning_rate = 2e-3, 
        per_device_train_batch_size = batch_size, 
        per_device_eval_batch_size = batch_size, 
        weight_decay = 0.01, 
        save_strategy="no", 
        num_train_epochs = 3, 
        predict_with_generate = True, 
        push_to_hub = False, 
        seed = seed
    )
    
    # Define Trainer with updated seed and reinitialize model
    trainer = Seq2SeqTrainer(
        model, 
        args, 
        train_dataset = train_dataset, 
        eval_dataset = val_dataset, 
        data_collator = data_collator, 
        tokenizer = tokenizer, 
    )
    
    # Train and generate predictions for each seed
    trainer.train()
    predictions, _, test_loss = test_model(model, test_loader)
    print(f"Test Loss: {test_loss}")
    all_predictions.append(predictions)

print("Ensembling complete")
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/training_args.py:1545: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='600' max='600' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [600/600 17:23, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.244652</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.228539</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.228700</td>
#       <td>0.243971</td>
#     </tr>
#   </tbody>
# </table><p>
# Generating Predictions and Calculating Test Loss:   0%|          | 0/125 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/transformers/generation/utils.py:1220: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Test Loss: 0.20442403507232665
# Test Loss: 0.20442403507232665
# /opt/conda/lib/python3.10/site-packages/transformers/training_args.py:1545: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='600' max='600' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [600/600 17:23, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.240001</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.228305</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.237900</td>
#       <td>0.245511</td>
#     </tr>
#   </tbody>
# </table><p>
# Generating Predictions and Calculating Test Loss:   0%|          | 0/125 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/transformers/generation/utils.py:1220: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Test Loss: 0.2073460247218609
# Test Loss: 0.2073460247218609
# /opt/conda/lib/python3.10/site-packages/transformers/training_args.py:1545: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='600' max='600' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [600/600 17:22, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.236434</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.226798</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.227800</td>
#       <td>0.242178</td>
#     </tr>
#   </tbody>
# </table><p>
# Generating Predictions and Calculating Test Loss:   0%|          | 0/125 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/transformers/generation/utils.py:1220: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Test Loss: 0.20018573880195617
# Test Loss: 0.20018573880195617
# /opt/conda/lib/python3.10/site-packages/transformers/training_args.py:1545: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='600' max='600' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [600/600 17:23, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.244277</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.231704</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.233600</td>
#       <td>0.240898</td>
#     </tr>
#   </tbody>
# </table><p>
# Generating Predictions and Calculating Test Loss:   0%|          | 0/125 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/transformers/generation/utils.py:1220: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Test Loss: 0.19755844765901565
# Test Loss: 0.19755844765901565
# /opt/conda/lib/python3.10/site-packages/transformers/training_args.py:1545: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='600' max='600' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [600/600 17:23, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.240886</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.225671</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.231600</td>
#       <td>0.239641</td>
#     </tr>
#   </tbody>
# </table><p>
# Generating Predictions and Calculating Test Loss:   0%|          | 0/125 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/transformers/generation/utils.py:1220: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Test Loss: 0.20104616290330887
# Test Loss: 0.20104616290330887
# Ensembling complete

# %%
from nltk import edit_distance
import numpy as np

# Post-hoc model ensembling using edit distance
ensemble_outputs = []

for i in range(len(test_dataset)):
    # Gather the i-th prediction from each model in the ensemble
    candidate_outputs = [pred[i] for pred in all_predictions]
    
    # Compute cumulative edit distances for each candidate
    total_edit_distances = []
    for j, output_j in enumerate(candidate_outputs):
        edit_distance_sum = sum(edit_distance(output_j, output_k) for k, output_k in enumerate(candidate_outputs) if j != k)
        total_edit_distances.append(edit_distance_sum)
    
    # Choose the candidate with the smallest total edit distance
    best_output = candidate_outputs[np.argmin(total_edit_distances)]
    ensemble_outputs.append(best_output)

# Save ensemble outputs to a JSON file
output_data = {"ensemble_predictions": ensemble_outputs}
with open('/kaggle/working/ensemble_predictions.json', 'w') as f:
    json.dump(output_data, f)
print("Saved ensemble predictions to ensemble_predictions.json")
# Out:
# Saved ensemble predictions to ensemble_predictions.json

# %%
# Function to generate only references
def get_references(dataloader):
    references = []
    progress_bar = tqdm(dataloader, desc="Extracting References", leave=False)
    with torch.no_grad():
        for batch in progress_bar:
            # Move batch to GPU if available
            inputs = {key: value.to('cuda' if torch.cuda.is_available() else 'cpu') for key, value in batch.items()}
            
            # Decode labels to get references
            refs = tokenizer.batch_decode(inputs['labels'], skip_special_tokens=True)
            
            # Store references
            references.extend(refs)
    
    return references

# Usage
references = get_references(test_loader)

predictions = ensemble_outputs

# Calculate BERTScore
bertscore_results = calculate_bertscore(predictions, references)

# Calculate BLEU-4
bleu_score = calculate_bleu(predictions, references)

# Calculate METEOR
# meteor_score = calculate_meteor(predictions, references)

# Display all results
print(f"TestLoss: {test_loss}")
print(f"BERTScore: {bertscore_results}")
print(f"BLEU-4 Score: {bleu_score}")
# print(f"METEOR Score: {meteor_score}")
# Out:
# Extracting References:   0%|          | 0/125 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# TestLoss: 0.20104616290330887
# BERTScore: {'precision': 0.890281617641449, 'recall': 0.8794229626655579, 'f1': 0.8842452168464661}
# BLEU-4 Score: 0.3099923793616025
